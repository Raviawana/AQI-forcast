# %%
import pandas as pd
import glob
import os

folder_path = "/Users/ravigurjar/Desktop/temp/sample/dessertation/data/raw"

# Get all CSV files in folder
all_files = glob.glob(os.path.join(folder_path, "*.xlsx"))

df_list = []

for file in all_files:
    df = pd.read_excel(file)
    df_list.append(df)
    print(f"Loaded: {os.path.basename(file)}  Shape: {df.shape}")
# Out:
# Loaded: Dataset_2.xlsx  Shape: (153, 11)
# Loaded: Dataset_3.xlsx  Shape: (153, 11)
# Loaded: Dataset_10.xlsx  Shape: (153, 11)
# Loaded: Dataset_8.xlsx  Shape: (153, 11)
# Loaded: Dataset_4.xlsx  Shape: (153, 11)
# Loaded: Dataset_5.xlsx  Shape: (153, 11)
# Loaded: Dataset_11.xlsx  Shape: (153, 11)
# Loaded: Dataset_9.xlsx  Shape: (153, 11)
# Loaded: Dataset_12.xlsx  Shape: (153, 11)
# Loaded: Dataset_6.xlsx  Shape: (153, 11)
# Loaded: Dataset_7.xlsx  Shape: (153, 11)
# Loaded: Dataset_1.xlsx  Shape: (153, 11)

# %%
merged_df = pd.concat(df_list, ignore_index=True)

# %%
import os

processed_folder = "/Users/ravigurjar/Desktop/temp/sample/dessertation/data/processed"
os.makedirs(processed_folder, exist_ok=True)

output_path = os.path.join(processed_folder, "merged_df.csv")

final_df.to_csv(output_path, index=False)
print("Saved successfully to:", output_path)
# Out:
# Saved successfully to: /Users/ravigurjar/Desktop/temp/sample/dessertation/data/processed/merged_df.csv

# %%
import pandas as pd
import requests

# 1. Load your Excel file
df = pd.read_csv("/Users/ravigurjar/Desktop/temp/sample/dessertation/data/processed/merged_df.csv").copy()

# ------------------------------------------------------------------
# 2. Parse Time → NASA date + hour
#    (adjust format=... if your Time string is different)
# ------------------------------------------------------------------
# This will handle common formats automatically (e.g. "2025-12-01 13:00:00" or "01-12-2025 13:00:00")
df["Time"] = pd.to_datetime(df["Time"], errors="coerce")

# Date in NASA format YYYYMMDD (string)
df["nasa_date"] = df["Time"].dt.strftime("%Y%m%d")

# Hour as 2-digit string ("00"–"23")
df["hour_str"] = df["Time"].dt.strftime("%H")

# %%
import pandas as pd
import requests


# ------------------------------------------------------------------
# 2. Parse Time → nasa_date
# ------------------------------------------------------------------
# If Time is like "01-12-2025 13:00:00", you can force the format:
# df["Time"] = pd.to_datetime(df["Time"], format="%d-%m-%Y %H:%M:%S", errors="coerce")
df["Time"] = pd.to_datetime(df["Time"], errors="coerce")

df["nasa_date"] = df["Time"].dt.strftime("%Y%m%d")  # '20240503'

print("Sample of time parsing:")
print(df[["Time", "nasa_date"]].head())

# ------------------------------------------------------------------
# 3. NASA POWER DAILY API configuration
# ------------------------------------------------------------------
BASE_URL = "https://power.larc.nasa.gov/api/temporal/daily/point"

# Daily meteorological parameters you want
# (these are valid for daily AG; you can add/remove if needed)
PARAMS = "T2M,RH2M,WS10M,WD10M,PRECTOTCORR"

def fetch_nasa_daily(lat, lon, date_str):
    """
    Fetch DAILY NASA POWER meteorology for a single (lat, lon, date_str='YYYYMMDD').
    Returns dict like:
      {
        "T2M": {"20240503": 28.5, ...},
        "RH2M": {"20240503": 65.3, ...},
        ...
      }
    or None if it fails.
    """
    url = (
        f"{BASE_URL}?parameters={PARAMS}"
        f"&community=AG"
        f"&latitude={lat}&longitude={lon}"
        f"&start={date_str}&end={date_str}"
        f"&format=JSON"
    )

    try:
        r = requests.get(url, timeout=30)
    except Exception as e:
        print(f"Request error for ({lat}, {lon}, {date_str}): {e}")
        return None

    if r.status_code != 200:
        print(f"Bad status {r.status_code} for ({lat}, {lon}, {date_str})")
        try:
            print("Response:", r.json())
        except Exception:
            pass
        return None

    data = r.json()
    try:
        params_dict = data["properties"]["parameter"]
    except KeyError:
        print(f"No 'parameter' key in NASA response for ({lat}, {lon}, {date_str})")
        return None

    return params_dict


def extract_daily_value(param_dict, var_name, date_str):
    """
    From NASA DAILY parameter dict, extract value at given date.
    Keys look like: '20240503'
    """
    if param_dict is None or var_name not in param_dict:
        return None

    series = param_dict[var_name]   # dict of { "YYYYMMDD": value }
    return series.get(date_str, None)

# ------------------------------------------------------------------
# 4. Build a separate NASA DAILY dataframe (no merge)
# ------------------------------------------------------------------
meteo_vars = ["T2M", "RH2M", "WS10M", "WD10M", "PRECTOTCORR"]

# unique (Latitude, Longitude, nasa_date) points in your dataset
unique_points = df[["Latitude", "Longitude", "nasa_date"]].drop_duplicates()

# cache NASA responses per (lat, lon, date) so we don't call for every row
cache = {}  # (lat, lon, nasa_date) -> param_dict

rows = []   # will hold rows for nasa_df

print("Unique (Latitude, Longitude, nasa_date) rows:", len(unique_points))

for _, p in unique_points.iterrows():
    lat = p["Latitude"]
    lon = p["Longitude"]
    date_str = p["nasa_date"]

    cache_key = (lat, lon, date_str)

    if cache_key not in cache:
        print(f"Fetching DAILY NASA data for lat={lat}, lon={lon}, date={date_str} ...")
        cache[cache_key] = fetch_nasa_daily(lat, lon, date_str)

    param_dict = cache[cache_key]

    # build one output row for this (lat, lon, date)
    out = {
        "Latitude": lat,
        "Longitude": lon,
        "nasa_date": date_str,
    }

    for var in meteo_vars:
        out[var] = extract_daily_value(param_dict, var, date_str)

    rows.append(out)

# Create separate NASA meteorology dataframe
nasa_df = pd.DataFrame(rows)

print("NASA DAILY meteo dataframe preview:")
print(nasa_df.head())

# Optionally save it to file for later merging
# nasa_df.to_excel("/Users/ravigurjar/Desktop/temp/sample/dessertation/data/NASA_meteo_daily_only.xlsx", index=False)
# Out:
# Sample of time parsing:
#                  Time nasa_date
# 0 2024-05-01 09:00:00  20240501
# 1 2024-05-01 05:00:00  20240501
# 2 2024-05-01 10:00:00  20240501
# 3 2020-11-19 16:00:00  20201119
# 4 2024-05-01 10:00:00  20240501
# Unique (Latitude, Longitude, nasa_date) rows: 987
# Fetching DAILY NASA data for lat=14.675886, lon=77.593027, date=20240501 ...
# Fetching DAILY NASA data for lat=16.9872867, lon=81.7363176, date=20240501 ...
# Fetching DAILY NASA data for lat=13.67, lon=79.35, date=20240501 ...
# Fetching DAILY NASA data for lat=16.507014, lon=80.627767, date=20201119 ...
# Fetching DAILY NASA data for lat=27.103358, lon=93.679645, date=20240501 ...
# Fetching DAILY NASA data for lat=26.1875, lon=91.744194, date=20240501 ...
# Fetching DAILY NASA data for lat=25.204762, lon=85.51496, date=20240501 ...
# Fetching DAILY NASA data for lat=25.5626095, lon=84.663264, date=20240501 ...
# Fetching DAILY NASA data for lat=25.444266, lon=86.140169, date=20231222 ...
# Fetching DAILY NASA data for lat=26.80365, lon=84.51954, date=20240501 ...
# Fetching DAILY NASA data for lat=25.251013, lon=86.989001, date=20240501 ...
# Fetching DAILY NASA data for lat=24.762518, lon=84.982348, date=20240501 ...
# Fetching DAILY NASA data for lat=25.555605, lon=83.950942, date=20221201 ...
# Fetching DAILY NASA data for lat=25.7808257, lon=84.7446768, date=20240501 ...
# Fetching DAILY NASA data for lat=26.15146, lon=85.89342, date=20230114 ...
# Fetching DAILY NASA data for lat=24.7955, lon=84.9994, date=20240501 ...
# Fetching DAILY NASA data for lat=25.697189, lon=85.2459, date=20240501 ...
# Fetching DAILY NASA data for lat=25.376776, lon=86.471523, date=20240501 ...
# Fetching DAILY NASA data for lat=25.560083, lon=87.553265, date=20240501 ...
# Fetching DAILY NASA data for lat=26.63086, lon=84.90051, date=20240501 ...
# Fetching DAILY NASA data for lat=26.11442, lon=85.39813, date=20240501 ...
# Fetching DAILY NASA data for lat=25.6103665, lon=85.1327137, date=20240501 ...
# Fetching DAILY NASA data for lat=25.892357, lon=86.590325, date=20240501 ...
# Fetching DAILY NASA data for lat=25.859655, lon=85.77944, date=20240501 ...
# Fetching DAILY NASA data for lat=26.2271665, lon=84.3570427, date=20240501 ...
# Fetching DAILY NASA data for lat=30.735567, lon=76.775714, date=20240501 ...
# Fetching DAILY NASA data for lat=21.185571, lon=81.343175, date=20240501 ...
# Fetching DAILY NASA data for lat=22.08815, lon=82.13737, date=20240501 ...
# Fetching DAILY NASA data for lat=30.269444, lon=78.044167, date=20240501 ...
# Fetching DAILY NASA data for lat=20.362421, lon=72.918013, date=20240501 ...
# Fetching DAILY NASA data for lat=28.63576, lon=77.22445, date=20240501 ...
# Fetching DAILY NASA data for lat=23.002657, lon=72.591912, date=20240501 ...
# Fetching DAILY NASA data for lat=21.613267, lon=73.010555, date=20240501 ...
# Fetching DAILY NASA data for lat=23.163798, lon=72.677768, date=20240501 ...
# Fetching DAILY NASA data for lat=53.58904, lon=142.94797, date=20220112 ...
# Fetching DAILY NASA data for lat=30.379589, lon=76.778328, date=20240501 ...
# Fetching DAILY NASA data for lat=28.806223, lon=76.141105, date=20240501 ...
# Fetching DAILY NASA data for lat=28.4088421, lon=77.3099081, date=20240501 ...
# Fetching DAILY NASA data for lat=29.14056, lon=75.744941, date=20240501 ...
# Fetching DAILY NASA data for lat=29.307814, lon=76.337619, date=20240501 ...
# Fetching DAILY NASA data for lat=29.8006, lon=76.4155, date=20240501 ...
# Fetching DAILY NASA data for lat=29.6953, lon=77.0027, date=20240501 ...
# Fetching DAILY NASA data for lat=28.870083, lon=76.6205, date=20200113 ...
# Fetching DAILY NASA data for lat=29.5364, lon=75.0158, date=20240501 ...
# Fetching DAILY NASA data for lat=29.0272, lon=77.0621, date=20240501 ...
# Fetching DAILY NASA data for lat=51.547479, lon=7.693785, date=20240501 ...
# Fetching DAILY NASA data for lat=34.066206, lon=74.81982, date=20240304 ...
# Fetching DAILY NASA data for lat=23.707909, lon=86.41467, date=20240430 ...
# Fetching DAILY NASA data for lat=12.938539, lon=77.5901, date=20240501 ...
# Fetching DAILY NASA data for lat=15.888653, lon=74.541751, date=20240501 ...
# Fetching DAILY NASA data for lat=13.328028, lon=75.797056, date=20240501 ...
# Fetching DAILY NASA data for lat=14.4758, lon=75.9052, date=20240501 ...
# Fetching DAILY NASA data for lat=13.008556, lon=76.125258, date=20240430 ...
# Fetching DAILY NASA data for lat=17.321993, lon=76.822628, date=20240501 ...
# Fetching DAILY NASA data for lat=13.1276288, lon=78.1570122, date=20240501 ...
# Fetching DAILY NASA data for lat=12.415911, lon=75.73505, date=20240501 ...
# Fetching DAILY NASA data for lat=12.88925, lon=74.853, date=20240501 ...
# Fetching DAILY NASA data for lat=16.208139, lon=77.348417, date=20240430 ...
# Fetching DAILY NASA data for lat=13.94, lon=75.555917, date=20240501 ...
# Fetching DAILY NASA data for lat=16.802639, lon=75.722694, date=20240501 ...
# Fetching DAILY NASA data for lat=11.875, lon=75.3732, date=20240501 ...
# Fetching DAILY NASA data for lat=33.5489621, lon=133.5987948, date=20240501 ...
# Fetching DAILY NASA data for lat=8.8787, lon=76.6073, date=20240430 ...
# Fetching DAILY NASA data for lat=8.5149093, lon=76.9435879, date=20240501 ...
# Fetching DAILY NASA data for lat=10.5324, lon=76.2159, date=20240501 ...
# Fetching DAILY NASA data for lat=49.5001917595947, lon=0.110902803971606, date=20240501 ...
# Fetching DAILY NASA data for lat=23.233584, lon=77.400574, date=20240501 ...
# Fetching DAILY NASA data for lat=23.81748678, lon=79.446246, date=20240122 ...
# Fetching DAILY NASA data for lat=22.9682591, lon=76.064118, date=20240501 ...
# Fetching DAILY NASA data for lat=26.210536, lon=78.171, date=20240501 ...
# Fetching DAILY NASA data for lat=23.168606, lon=79.932247, date=20240501 ...
# Fetching DAILY NASA data for lat=23.331731, lon=75.045981, date=20240501 ...
# Fetching DAILY NASA data for lat=23.8640158, lon=78.80289321, date=20240501 ...
# Fetching DAILY NASA data for lat=24.58434363, lon=80.8549414, date=20240501 ...
# Fetching DAILY NASA data for lat=23.182719, lon=75.768218, date=20240501 ...
# Fetching DAILY NASA data for lat=24.75746, lon=84.366208, date=20240501 ...
# Fetching DAILY NASA data for lat=19.9775302, lon=79.2337086, date=20240425 ...
# Fetching DAILY NASA data for lat=34.2875011, lon=48.787992, date=20240501 ...
# Fetching DAILY NASA data for lat=19.25292, lon=73.142019, date=20240501 ...
# Fetching DAILY NASA data for lat=19.072830200195, lon=72.882606506348, date=20240429 ...
# Fetching DAILY NASA data for lat=21.152875, lon=79.0517531, date=20240501 ...
# Fetching DAILY NASA data for lat=20.0073285, lon=73.7762427, date=20240501 ...
# Fetching DAILY NASA data for lat=18.529603, lon=73.849586, date=20211115 ...
# Fetching DAILY NASA data for lat=17.6599188, lon=75.9063906, date=20240501 ...
# Fetching DAILY NASA data for lat=19.192056, lon=72.9585188, date=20240430 ...
# Fetching DAILY NASA data for lat=24.8207389, lon=93.9423085, date=20240501 ...
# Fetching DAILY NASA data for lat=25.5586, lon=91.8985, date=20240501 ...
# Fetching DAILY NASA data for lat=23.7176342, lon=92.7192841, date=20240501 ...
# Fetching DAILY NASA data for lat=25.6635413, lon=94.0989878, date=20240501 ...
# Fetching DAILY NASA data for lat=50.4651921586212, lon=3.93971432591091, date=20240501 ...
# Fetching DAILY NASA data for lat=11.9309, lon=79.8027, date=20240501 ...
# Fetching DAILY NASA data for lat=31.62, lon=74.876512, date=20240501 ...
# Fetching DAILY NASA data for lat=31.321907, lon=75.578914, date=20240501 ...
# Fetching DAILY NASA data for lat=30.9028, lon=75.8086, date=20240501 ...
# Fetching DAILY NASA data for lat=30.349388, lon=76.366642, date=20240501 ...
# Fetching DAILY NASA data for lat=31.0325454, lon=76.5623046, date=20240501 ...
# Fetching DAILY NASA data for lat=26.470859, lon=74.646594, date=20240501 ...
# Fetching DAILY NASA data for lat=27.554793, lon=76.611536, date=20240501 ...
# Fetching DAILY NASA data for lat=45.262666665757, lon=1.76283333333, date=20240501 ...
# Fetching DAILY NASA data for lat=26.9164092, lon=75.7994901, date=20240501 ...
# Fetching DAILY NASA data for lat=26.268249, lon=73.0193853, date=20240501 ...
# Fetching DAILY NASA data for lat=25.14389, lon=75.821256, date=20240501 ...
# Fetching DAILY NASA data for lat=25.771061, lon=73.340227, date=20240501 ...
# Fetching DAILY NASA data for lat=24.5886166, lon=73.6321397, date=20240501 ...
# Fetching DAILY NASA data for lat=27.33853, lon=88.614099, date=20240501 ...
# Fetching DAILY NASA data for lat=13.087840080261, lon=80.278472900391, date=20240501 ...
# Fetching DAILY NASA data for lat=10.942451, lon=76.978996, date=20230721 ...
# Fetching DAILY NASA data for lat=10.358535, lon=77.984321, date=20230725 ...
# Fetching DAILY NASA data for lat=9.36399, lon=78.831977, date=20240501 ...
# Fetching DAILY NASA data for lat=44.943114, lon=-123.005934, date=20240430 ...
# Fetching DAILY NASA data for lat=11.0973603, lon=77.3228673, date=20240430 ...
# Fetching DAILY NASA data for lat=8.816428, lon=78.099039, date=20240501 ...
# Fetching DAILY NASA data for lat=11.4068288, lon=76.7138973, date=20240501 ...
# Fetching DAILY NASA data for lat=17.384050369263, lon=78.456359863281, date=20240501 ...
# Fetching DAILY NASA data for lat=17.585705, lon=78.126199, date=20240501 ...
# Fetching DAILY NASA data for lat=23.8175497, lon=91.2726974, date=20240501 ...
# Fetching DAILY NASA data for lat=27.19865833, lon=78.00598056, date=20240501 ...
# Fetching DAILY NASA data for lat=28.38910936, lon=79.42963708, date=20240501 ...
# Fetching DAILY NASA data for lat=28.406963, lon=77.849831, date=20240501 ...
# Fetching DAILY NASA data for lat=28.685382, lon=77.453839, date=20240501 ...
# Fetching DAILY NASA data for lat=26.730136, lon=83.433859, date=20240501 ...
# Fetching DAILY NASA data for lat=25.4547, lon=78.6039, date=20240501 ...
# Fetching DAILY NASA data for lat=26.428282, lon=80.327067, date=20240501 ...
# Fetching DAILY NASA data for lat=26.766433, lon=80.927299, date=20240501 ...
# Fetching DAILY NASA data for lat=27.571409, lon=77.655757, date=20240501 ...
# Fetching DAILY NASA data for lat=29.06351, lon=77.709723, date=20240501 ...
# Fetching DAILY NASA data for lat=28.856664, lon=78.772638, date=20240501 ...
# Fetching DAILY NASA data for lat=29.4723508, lon=77.7194031, date=20240501 ...
# Fetching DAILY NASA data for lat=25.32393, lon=82.99687, date=20240501 ...
# Fetching DAILY NASA data for lat=30.455449, lon=78.100618, date=nan ...
# Bad status 422 for (30.455449, 78.100618, nan)
# Response: {'detail': [{'type': 'int_parsing', 'loc': ['query', 'start'], 'msg': 'Input should be a valid integer, unable to parse string as an integer', 'input': 'nan'}, {'type': 'int_parsing', 'loc': ['query', 'end'], 'msg': 'Input should be a valid integer, unable to parse string as an integer', 'input': 'nan'}]}
# Fetching DAILY NASA data for lat=23.685297, lon=86.945968, date=20240501 ...
# Fetching DAILY NASA data for lat=22.611968, lon=88.347422, date=20240501 ...
# Fetching DAILY NASA data for lat=22.627847, lon=88.380669, date=20240501 ...
# Fetching DAILY NASA data for lat=22.58157048, lon=88.41002457, date=20240501 ...
# Fetching DAILY NASA data for lat=23.5404352, lon=87.2892225, date=20240501 ...
# Fetching DAILY NASA data for lat=22.5448082, lon=88.3403691, date=20240501 ...
# Fetching DAILY NASA data for lat=22.562629699707, lon=88.363037109375, date=20240501 ...
# Fetching DAILY NASA data for lat=26.6883049, lon=88.412668, date=20240501 ...
# Fetching DAILY NASA data for lat=14.675886, lon=77.593027, date=20240502 ...
# Fetching DAILY NASA data for lat=13.67, lon=79.35, date=20240502 ...
# Fetching DAILY NASA data for lat=27.103358, lon=93.679645, date=20240502 ...
# Fetching DAILY NASA data for lat=26.1875, lon=91.744194, date=20240502 ...
# Fetching DAILY NASA data for lat=25.204762, lon=85.51496, date=20240502 ...
# Fetching DAILY NASA data for lat=25.5626095, lon=84.663264, date=20240502 ...
# Fetching DAILY NASA data for lat=26.80365, lon=84.51954, date=20240502 ...
# Fetching DAILY NASA data for lat=25.251013, lon=86.989001, date=20240502 ...
# Fetching DAILY NASA data for lat=24.762518, lon=84.982348, date=20240502 ...
# Fetching DAILY NASA data for lat=25.7808257, lon=84.7446768, date=20240502 ...
# Fetching DAILY NASA data for lat=24.7955, lon=84.9994, date=20240502 ...
# Fetching DAILY NASA data for lat=25.697189, lon=85.2459, date=20240502 ...
# Fetching DAILY NASA data for lat=25.376776, lon=86.471523, date=20240502 ...
# Fetching DAILY NASA data for lat=25.560083, lon=87.553265, date=20240502 ...
# Fetching DAILY NASA data for lat=26.63086, lon=84.90051, date=20240502 ...
# Fetching DAILY NASA data for lat=26.11442, lon=85.39813, date=20240502 ...
# Fetching DAILY NASA data for lat=25.6103665, lon=85.1327137, date=20240502 ...
# Fetching DAILY NASA data for lat=25.892357, lon=86.590325, date=20240502 ...
# Fetching DAILY NASA data for lat=25.859655, lon=85.77944, date=20240502 ...
# Fetching DAILY NASA data for lat=30.735567, lon=76.775714, date=20240502 ...
# Fetching DAILY NASA data for lat=21.185571, lon=81.343175, date=20240502 ...
# Fetching DAILY NASA data for lat=22.08815, lon=82.13737, date=20240502 ...
# Fetching DAILY NASA data for lat=30.269444, lon=78.044167, date=20240502 ...
# Fetching DAILY NASA data for lat=20.362421, lon=72.918013, date=20240502 ...
# Fetching DAILY NASA data for lat=28.63576, lon=77.22445, date=20240502 ...
# Fetching DAILY NASA data for lat=23.002657, lon=72.591912, date=20240502 ...
# Fetching DAILY NASA data for lat=21.613267, lon=73.010555, date=20240502 ...
# Fetching DAILY NASA data for lat=23.163798, lon=72.677768, date=20240502 ...
# Fetching DAILY NASA data for lat=30.379589, lon=76.778328, date=20240502 ...
# Fetching DAILY NASA data for lat=28.806223, lon=76.141105, date=20240502 ...
# Fetching DAILY NASA data for lat=29.14056, lon=75.744941, date=20240502 ...
# Fetching DAILY NASA data for lat=29.307814, lon=76.337619, date=20240502 ...
# Fetching DAILY NASA data for lat=29.8006, lon=76.4155, date=20240502 ...
# Fetching DAILY NASA data for lat=29.6953, lon=77.0027, date=20240502 ...
# Fetching DAILY NASA data for lat=29.5364, lon=75.0158, date=20240502 ...
# Fetching DAILY NASA data for lat=29.0272, lon=77.0621, date=20240502 ...
# Fetching DAILY NASA data for lat=51.547479, lon=7.693785, date=20240502 ...
# Fetching DAILY NASA data for lat=23.707909, lon=86.41467, date=20240502 ...
# Fetching DAILY NASA data for lat=12.938539, lon=77.5901, date=20240502 ...
# Fetching DAILY NASA data for lat=15.888653, lon=74.541751, date=20240502 ...
# Fetching DAILY NASA data for lat=13.328028, lon=75.797056, date=20240502 ...
# Fetching DAILY NASA data for lat=14.4758, lon=75.9052, date=20240502 ...
# Fetching DAILY NASA data for lat=13.008556, lon=76.125258, date=20240501 ...
# Fetching DAILY NASA data for lat=17.321993, lon=76.822628, date=20240502 ...
# Fetching DAILY NASA data for lat=13.1276288, lon=78.1570122, date=20240502 ...
# Fetching DAILY NASA data for lat=12.415911, lon=75.73505, date=20240502 ...
# Fetching DAILY NASA data for lat=12.88925, lon=74.853, date=20240502 ...
# Fetching DAILY NASA data for lat=13.94, lon=75.555917, date=20240502 ...
# Fetching DAILY NASA data for lat=16.802639, lon=75.722694, date=20240502 ...
# Fetching DAILY NASA data for lat=11.875, lon=75.3732, date=20240502 ...
# Fetching DAILY NASA data for lat=33.5489621, lon=133.5987948, date=20240502 ...
# Fetching DAILY NASA data for lat=8.8787, lon=76.6073, date=20240502 ...
# Fetching DAILY NASA data for lat=8.5149093, lon=76.9435879, date=20240502 ...
# Fetching DAILY NASA data for lat=10.5324, lon=76.2159, date=20240502 ...
# Fetching DAILY NASA data for lat=49.5001917595947, lon=0.110902803971606, date=20240502 ...
# Fetching DAILY NASA data for lat=23.233584, lon=77.400574, date=20240502 ...
# Fetching DAILY NASA data for lat=22.9682591, lon=76.064118, date=20240502 ...
# Fetching DAILY NASA data for lat=26.210536, lon=78.171, date=20240502 ...
# Fetching DAILY NASA data for lat=23.168606, lon=79.932247, date=20240502 ...
# Fetching DAILY NASA data for lat=23.331731, lon=75.045981, date=20240502 ...
# Fetching DAILY NASA data for lat=23.8640158, lon=78.80289321, date=20240502 ...
# Fetching DAILY NASA data for lat=24.75746, lon=84.366208, date=20240502 ...
# Fetching DAILY NASA data for lat=34.2875011, lon=48.787992, date=20240502 ...
# Fetching DAILY NASA data for lat=19.25292, lon=73.142019, date=20240502 ...
# Fetching DAILY NASA data for lat=21.152875, lon=79.0517531, date=20240502 ...
# Fetching DAILY NASA data for lat=20.0073285, lon=73.7762427, date=20240502 ...
# Fetching DAILY NASA data for lat=17.6599188, lon=75.9063906, date=20240502 ...
# Fetching DAILY NASA data for lat=19.192056, lon=72.9585188, date=20240502 ...
# Fetching DAILY NASA data for lat=24.8207389, lon=93.9423085, date=20240502 ...
# Fetching DAILY NASA data for lat=25.5586, lon=91.8985, date=20240502 ...
# Fetching DAILY NASA data for lat=23.7176342, lon=92.7192841, date=20240502 ...
# Fetching DAILY NASA data for lat=25.6635413, lon=94.0989878, date=20240502 ...
# Fetching DAILY NASA data for lat=50.4651921586212, lon=3.93971432591091, date=20240502 ...
# Fetching DAILY NASA data for lat=11.9309, lon=79.8027, date=20240502 ...
# Fetching DAILY NASA data for lat=31.62, lon=74.876512, date=20240502 ...
# Fetching DAILY NASA data for lat=31.321907, lon=75.578914, date=20240502 ...
# Fetching DAILY NASA data for lat=30.9028, lon=75.8086, date=20240502 ...
# Fetching DAILY NASA data for lat=30.349388, lon=76.366642, date=20240502 ...
# Fetching DAILY NASA data for lat=31.0325454, lon=76.5623046, date=20240502 ...
# Fetching DAILY NASA data for lat=26.470859, lon=74.646594, date=20240502 ...
# Fetching DAILY NASA data for lat=27.554793, lon=76.611536, date=20240502 ...
# Fetching DAILY NASA data for lat=45.262666665757, lon=1.76283333333, date=20240502 ...
# Fetching DAILY NASA data for lat=26.9164092, lon=75.7994901, date=20240502 ...
# Fetching DAILY NASA data for lat=26.268249, lon=73.0193853, date=20240502 ...
# Fetching DAILY NASA data for lat=25.14389, lon=75.821256, date=20240502 ...
# Fetching DAILY NASA data for lat=25.771061, lon=73.340227, date=20240502 ...
# Fetching DAILY NASA data for lat=24.5886166, lon=73.6321397, date=20240502 ...
# Fetching DAILY NASA data for lat=27.33853, lon=88.614099, date=20240502 ...
# Fetching DAILY NASA data for lat=13.087840080261, lon=80.278472900391, date=20240502 ...
# Fetching DAILY NASA data for lat=9.36399, lon=78.831977, date=20240502 ...
# Fetching DAILY NASA data for lat=44.943114, lon=-123.005934, date=20240501 ...
# Fetching DAILY NASA data for lat=11.0973603, lon=77.3228673, date=20240502 ...
# Fetching DAILY NASA data for lat=8.816428, lon=78.099039, date=20240502 ...
# Fetching DAILY NASA data for lat=11.4068288, lon=76.7138973, date=20240502 ...
# Fetching DAILY NASA data for lat=17.384050369263, lon=78.456359863281, date=20240502 ...
# Fetching DAILY NASA data for lat=17.585705, lon=78.126199, date=20240502 ...
# Fetching DAILY NASA data for lat=23.8175497, lon=91.2726974, date=20240502 ...
# Fetching DAILY NASA data for lat=27.19865833, lon=78.00598056, date=20240502 ...
# Fetching DAILY NASA data for lat=28.38910936, lon=79.42963708, date=20240502 ...
# Fetching DAILY NASA data for lat=28.406963, lon=77.849831, date=20240502 ...
# Fetching DAILY NASA data for lat=28.685382, lon=77.453839, date=20240502 ...
# Fetching DAILY NASA data for lat=26.730136, lon=83.433859, date=20240502 ...
# Fetching DAILY NASA data for lat=25.4547, lon=78.6039, date=20240502 ...
# Fetching DAILY NASA data for lat=26.428282, lon=80.327067, date=20240502 ...
# Fetching DAILY NASA data for lat=26.766433, lon=80.927299, date=20240502 ...
# Fetching DAILY NASA data for lat=27.571409, lon=77.655757, date=20240502 ...
# Fetching DAILY NASA data for lat=29.06351, lon=77.709723, date=20240502 ...
# Fetching DAILY NASA data for lat=28.856664, lon=78.772638, date=20240502 ...
# Fetching DAILY NASA data for lat=29.4723508, lon=77.7194031, date=20240502 ...
# Fetching DAILY NASA data for lat=25.32393, lon=82.99687, date=20240502 ...
# Fetching DAILY NASA data for lat=23.685297, lon=86.945968, date=20240502 ...
# Fetching DAILY NASA data for lat=22.611968, lon=88.347422, date=20240502 ...
# Fetching DAILY NASA data for lat=22.627847, lon=88.380669, date=20240502 ...
# Fetching DAILY NASA data for lat=22.58157048, lon=88.41002457, date=20240502 ...
# Fetching DAILY NASA data for lat=23.5404352, lon=87.2892225, date=20240502 ...
# Fetching DAILY NASA data for lat=22.5448082, lon=88.3403691, date=20240502 ...
# Fetching DAILY NASA data for lat=22.562629699707, lon=88.363037109375, date=20240502 ...
# Fetching DAILY NASA data for lat=26.6883049, lon=88.412668, date=20240502 ...
# Fetching DAILY NASA data for lat=14.675886, lon=77.593027, date=20240424 ...
# Fetching DAILY NASA data for lat=16.9872867, lon=81.7363176, date=20240424 ...
# Fetching DAILY NASA data for lat=13.67, lon=79.35, date=20240424 ...
# Fetching DAILY NASA data for lat=27.103358, lon=93.679645, date=20240424 ...
# Fetching DAILY NASA data for lat=26.1875, lon=91.744194, date=20240423 ...
# Fetching DAILY NASA data for lat=25.204762, lon=85.51496, date=20240424 ...
# Fetching DAILY NASA data for lat=25.5626095, lon=84.663264, date=20240424 ...
# Fetching DAILY NASA data for lat=26.80365, lon=84.51954, date=20240424 ...
# Fetching DAILY NASA data for lat=25.251013, lon=86.989001, date=20240424 ...
# Fetching DAILY NASA data for lat=24.762518, lon=84.982348, date=20240424 ...
# Fetching DAILY NASA data for lat=25.7808257, lon=84.7446768, date=20240424 ...
# Fetching DAILY NASA data for lat=24.7955, lon=84.9994, date=20240424 ...
# Fetching DAILY NASA data for lat=25.697189, lon=85.2459, date=20240424 ...
# Fetching DAILY NASA data for lat=25.376776, lon=86.471523, date=20240424 ...
# Fetching DAILY NASA data for lat=25.560083, lon=87.553265, date=20240424 ...
# Fetching DAILY NASA data for lat=26.63086, lon=84.90051, date=20240424 ...
# Fetching DAILY NASA data for lat=26.11442, lon=85.39813, date=20240424 ...
# Fetching DAILY NASA data for lat=25.6103665, lon=85.1327137, date=20240424 ...
# Fetching DAILY NASA data for lat=25.892357, lon=86.590325, date=20240424 ...
# Fetching DAILY NASA data for lat=25.859655, lon=85.77944, date=20240424 ...
# Fetching DAILY NASA data for lat=26.2271665, lon=84.3570427, date=20240424 ...
# Fetching DAILY NASA data for lat=30.735567, lon=76.775714, date=20240424 ...
# Fetching DAILY NASA data for lat=21.185571, lon=81.343175, date=20240424 ...
# Fetching DAILY NASA data for lat=22.08815, lon=82.13737, date=20240424 ...
# Fetching DAILY NASA data for lat=30.269444, lon=78.044167, date=20240424 ...
# Fetching DAILY NASA data for lat=20.362421, lon=72.918013, date=20240424 ...
# Fetching DAILY NASA data for lat=28.63576, lon=77.22445, date=20240424 ...
# Fetching DAILY NASA data for lat=23.002657, lon=72.591912, date=20240424 ...
# Fetching DAILY NASA data for lat=21.613267, lon=73.010555, date=20240424 ...
# Fetching DAILY NASA data for lat=23.243639, lon=72.68994, date=20240424 ...
# Fetching DAILY NASA data for lat=30.379589, lon=76.778328, date=20240424 ...
# Fetching DAILY NASA data for lat=28.806223, lon=76.141105, date=20240424 ...
# Fetching DAILY NASA data for lat=28.4088421, lon=77.3099081, date=20240424 ...
# Fetching DAILY NASA data for lat=29.14056, lon=75.744941, date=20240424 ...
# Fetching DAILY NASA data for lat=29.307814, lon=76.337619, date=20240424 ...
# Fetching DAILY NASA data for lat=29.8006, lon=76.4155, date=20240424 ...
# Fetching DAILY NASA data for lat=29.6953, lon=77.0027, date=20240424 ...
# Fetching DAILY NASA data for lat=29.5364, lon=75.0158, date=20240424 ...
# Fetching DAILY NASA data for lat=29.0272, lon=77.0621, date=20240424 ...
# Fetching DAILY NASA data for lat=51.547479, lon=7.693785, date=20240424 ...
# Fetching DAILY NASA data for lat=23.707909, lon=86.41467, date=20240424 ...
# Fetching DAILY NASA data for lat=12.938539, lon=77.5901, date=20240424 ...
# Fetching DAILY NASA data for lat=15.888653, lon=74.541751, date=20240424 ...
# Fetching DAILY NASA data for lat=13.328028, lon=75.797056, date=20240424 ...
# Fetching DAILY NASA data for lat=14.4758, lon=75.9052, date=20240424 ...
# Fetching DAILY NASA data for lat=13.008556, lon=76.125258, date=20240424 ...
# Fetching DAILY NASA data for lat=17.321993, lon=76.822628, date=20240424 ...
# Fetching DAILY NASA data for lat=13.1276288, lon=78.1570122, date=20240424 ...
# Fetching DAILY NASA data for lat=12.415911, lon=75.73505, date=20240424 ...
# Fetching DAILY NASA data for lat=12.88925, lon=74.853, date=20240424 ...
# Fetching DAILY NASA data for lat=16.208139, lon=77.348417, date=20240424 ...
# Fetching DAILY NASA data for lat=13.94, lon=75.555917, date=20240424 ...
# Fetching DAILY NASA data for lat=16.802639, lon=75.722694, date=20240424 ...
# Fetching DAILY NASA data for lat=11.875, lon=75.3732, date=20240424 ...
# Fetching DAILY NASA data for lat=33.5489621, lon=133.5987948, date=20240424 ...
# Fetching DAILY NASA data for lat=8.8787, lon=76.6073, date=20240424 ...
# Fetching DAILY NASA data for lat=8.5149093, lon=76.9435879, date=20240424 ...
# Fetching DAILY NASA data for lat=10.5324, lon=76.2159, date=20240424 ...
# Fetching DAILY NASA data for lat=49.5001917595947, lon=0.110902803971606, date=20240424 ...
# Fetching DAILY NASA data for lat=23.233584, lon=77.400574, date=20240424 ...
# Fetching DAILY NASA data for lat=22.9682591, lon=76.064118, date=20240424 ...
# Fetching DAILY NASA data for lat=26.210536, lon=78.171, date=20240424 ...
# Fetching DAILY NASA data for lat=23.168606, lon=79.932247, date=20240424 ...
# Fetching DAILY NASA data for lat=23.331731, lon=75.045981, date=20240424 ...
# Fetching DAILY NASA data for lat=23.8640158, lon=78.80289321, date=20240424 ...
# Fetching DAILY NASA data for lat=24.58434363, lon=80.8549414, date=20240424 ...
# Fetching DAILY NASA data for lat=23.182719, lon=75.768218, date=20240424 ...
# Fetching DAILY NASA data for lat=24.75746, lon=84.366208, date=20240423 ...
# Fetching DAILY NASA data for lat=19.9775302, lon=79.2337086, date=20240424 ...
# Fetching DAILY NASA data for lat=34.2875011, lon=48.787992, date=20240424 ...
# Fetching DAILY NASA data for lat=19.25292, lon=73.142019, date=20240424 ...
# Fetching DAILY NASA data for lat=19.072830200195, lon=72.882606506348, date=20240424 ...
# Fetching DAILY NASA data for lat=21.152875, lon=79.0517531, date=20240424 ...
# Fetching DAILY NASA data for lat=20.0073285, lon=73.7762427, date=20240424 ...
# Fetching DAILY NASA data for lat=17.6599188, lon=75.9063906, date=20240424 ...
# Fetching DAILY NASA data for lat=19.192056, lon=72.9585188, date=20240424 ...
# Fetching DAILY NASA data for lat=24.8207389, lon=93.9423085, date=20240424 ...
# Fetching DAILY NASA data for lat=25.5586, lon=91.8985, date=20240424 ...
# Fetching DAILY NASA data for lat=23.7176342, lon=92.7192841, date=20240424 ...
# Fetching DAILY NASA data for lat=25.6635413, lon=94.0989878, date=20240424 ...
# Fetching DAILY NASA data for lat=50.4651921586212, lon=3.93971432591091, date=20240424 ...
# Fetching DAILY NASA data for lat=11.9309, lon=79.8027, date=20240424 ...
# Fetching DAILY NASA data for lat=31.62, lon=74.876512, date=20240424 ...
# Fetching DAILY NASA data for lat=31.321907, lon=75.578914, date=20240424 ...
# Fetching DAILY NASA data for lat=30.9028, lon=75.8086, date=20240424 ...
# Fetching DAILY NASA data for lat=30.349388, lon=76.366642, date=20240424 ...
# Fetching DAILY NASA data for lat=31.0325454, lon=76.5623046, date=20240424 ...
# Fetching DAILY NASA data for lat=26.470859, lon=74.646594, date=20240424 ...
# Fetching DAILY NASA data for lat=27.554793, lon=76.611536, date=20240424 ...
# Fetching DAILY NASA data for lat=45.262666665757, lon=1.76283333333, date=20240424 ...
# Fetching DAILY NASA data for lat=26.9164092, lon=75.7994901, date=20240424 ...
# Fetching DAILY NASA data for lat=26.268249, lon=73.0193853, date=20240424 ...
# Fetching DAILY NASA data for lat=25.14389, lon=75.821256, date=20240424 ...
# Fetching DAILY NASA data for lat=25.771061, lon=73.340227, date=20240424 ...
# Fetching DAILY NASA data for lat=24.5886166, lon=73.6321397, date=20240424 ...
# Fetching DAILY NASA data for lat=27.33853, lon=88.614099, date=20240424 ...
# Fetching DAILY NASA data for lat=13.087840080261, lon=80.278472900391, date=20240424 ...
# Fetching DAILY NASA data for lat=9.36399, lon=78.831977, date=20240424 ...
# Fetching DAILY NASA data for lat=44.943114, lon=-123.005934, date=20240424 ...
# Fetching DAILY NASA data for lat=11.0973603, lon=77.3228673, date=20240424 ...
# Fetching DAILY NASA data for lat=8.816428, lon=78.099039, date=20240424 ...
# Fetching DAILY NASA data for lat=11.4068288, lon=76.7138973, date=20240424 ...
# Fetching DAILY NASA data for lat=17.384050369263, lon=78.456359863281, date=20240422 ...
# Fetching DAILY NASA data for lat=17.585705, lon=78.126199, date=20240424 ...
# Fetching DAILY NASA data for lat=23.8175497, lon=91.2726974, date=20240424 ...
# Fetching DAILY NASA data for lat=27.19865833, lon=78.00598056, date=20240424 ...
# Fetching DAILY NASA data for lat=28.38910936, lon=79.42963708, date=20240424 ...
# Fetching DAILY NASA data for lat=28.406963, lon=77.849831, date=20240424 ...
# Fetching DAILY NASA data for lat=28.685382, lon=77.453839, date=20240424 ...
# Fetching DAILY NASA data for lat=26.730136, lon=83.433859, date=20240424 ...
# Fetching DAILY NASA data for lat=25.4547, lon=78.6039, date=20240424 ...
# Fetching DAILY NASA data for lat=26.428282, lon=80.327067, date=20240424 ...
# Fetching DAILY NASA data for lat=26.766433, lon=80.927299, date=20240424 ...
# Fetching DAILY NASA data for lat=27.571409, lon=77.655757, date=20240424 ...
# Fetching DAILY NASA data for lat=29.06351, lon=77.709723, date=20240424 ...
# Fetching DAILY NASA data for lat=28.856664, lon=78.772638, date=20240424 ...
# Fetching DAILY NASA data for lat=29.4723508, lon=77.7194031, date=20240424 ...
# Fetching DAILY NASA data for lat=25.32393, lon=82.99687, date=20240424 ...
# Fetching DAILY NASA data for lat=23.685297, lon=86.945968, date=20240424 ...
# Fetching DAILY NASA data for lat=22.611968, lon=88.347422, date=20240424 ...
# Fetching DAILY NASA data for lat=22.627847, lon=88.380669, date=20240424 ...
# Fetching DAILY NASA data for lat=22.58157048, lon=88.41002457, date=20240424 ...
# Fetching DAILY NASA data for lat=23.5404352, lon=87.2892225, date=20240424 ...
# Fetching DAILY NASA data for lat=22.5448082, lon=88.3403691, date=20240424 ...
# Fetching DAILY NASA data for lat=22.562629699707, lon=88.363037109375, date=20240424 ...
# Fetching DAILY NASA data for lat=26.6883049, lon=88.412668, date=20240424 ...
# Fetching DAILY NASA data for lat=14.675886, lon=77.593027, date=20240422 ...
# Fetching DAILY NASA data for lat=16.9872867, lon=81.7363176, date=20240422 ...
# Fetching DAILY NASA data for lat=13.67, lon=79.35, date=20240422 ...
# Fetching DAILY NASA data for lat=27.103358, lon=93.679645, date=20240422 ...
# Fetching DAILY NASA data for lat=26.1875, lon=91.744194, date=20240418 ...
# Fetching DAILY NASA data for lat=25.204762, lon=85.51496, date=20240422 ...
# Fetching DAILY NASA data for lat=25.5626095, lon=84.663264, date=20240422 ...
# Fetching DAILY NASA data for lat=26.80365, lon=84.51954, date=20240422 ...
# Fetching DAILY NASA data for lat=25.251013, lon=86.989001, date=20240422 ...
# Fetching DAILY NASA data for lat=24.762518, lon=84.982348, date=20240422 ...
# Fetching DAILY NASA data for lat=25.7808257, lon=84.7446768, date=20240422 ...
# Fetching DAILY NASA data for lat=24.7955, lon=84.9994, date=20240422 ...
# Fetching DAILY NASA data for lat=25.697189, lon=85.2459, date=20240422 ...
# Fetching DAILY NASA data for lat=25.376776, lon=86.471523, date=20240422 ...
# Fetching DAILY NASA data for lat=25.560083, lon=87.553265, date=20240422 ...
# Fetching DAILY NASA data for lat=26.63086, lon=84.90051, date=20240422 ...
# Fetching DAILY NASA data for lat=26.11442, lon=85.39813, date=20240422 ...
# Fetching DAILY NASA data for lat=25.6103665, lon=85.1327137, date=20240422 ...
# Fetching DAILY NASA data for lat=25.892357, lon=86.590325, date=20240422 ...
# Fetching DAILY NASA data for lat=25.859655, lon=85.77944, date=20240422 ...
# Fetching DAILY NASA data for lat=26.2271665, lon=84.3570427, date=20240422 ...
# Fetching DAILY NASA data for lat=30.735567, lon=76.775714, date=20240422 ...
# Fetching DAILY NASA data for lat=21.185571, lon=81.343175, date=20240422 ...
# Fetching DAILY NASA data for lat=22.08815, lon=82.13737, date=20240422 ...
# Fetching DAILY NASA data for lat=30.269444, lon=78.044167, date=20240422 ...
# Fetching DAILY NASA data for lat=20.362421, lon=72.918013, date=20240422 ...
# Fetching DAILY NASA data for lat=28.63576, lon=77.22445, date=20240422 ...
# Fetching DAILY NASA data for lat=23.002657, lon=72.591912, date=20240422 ...
# Fetching DAILY NASA data for lat=21.613267, lon=73.010555, date=20240422 ...
# Fetching DAILY NASA data for lat=23.243639, lon=72.68994, date=20240422 ...
# Fetching DAILY NASA data for lat=30.379589, lon=76.778328, date=20240422 ...
# Fetching DAILY NASA data for lat=28.806223, lon=76.141105, date=20240422 ...
# Fetching DAILY NASA data for lat=28.4088421, lon=77.3099081, date=20240422 ...
# Fetching DAILY NASA data for lat=29.14056, lon=75.744941, date=20240422 ...
# Fetching DAILY NASA data for lat=29.307814, lon=76.337619, date=20240422 ...
# Fetching DAILY NASA data for lat=29.8006, lon=76.4155, date=20240422 ...
# Fetching DAILY NASA data for lat=29.6953, lon=77.0027, date=20240422 ...
# Fetching DAILY NASA data for lat=29.5364, lon=75.0158, date=20240422 ...
# Fetching DAILY NASA data for lat=29.0272, lon=77.0621, date=20240422 ...
# Fetching DAILY NASA data for lat=51.547479, lon=7.693785, date=20240422 ...
# Fetching DAILY NASA data for lat=23.707909, lon=86.41467, date=20240422 ...
# Fetching DAILY NASA data for lat=12.938539, lon=77.5901, date=20240422 ...
# Fetching DAILY NASA data for lat=15.888653, lon=74.541751, date=20240422 ...
# Fetching DAILY NASA data for lat=13.328028, lon=75.797056, date=20240422 ...
# Fetching DAILY NASA data for lat=14.4758, lon=75.9052, date=20240422 ...
# Fetching DAILY NASA data for lat=13.008556, lon=76.125258, date=20240422 ...
# Fetching DAILY NASA data for lat=17.321993, lon=76.822628, date=20240422 ...
# Fetching DAILY NASA data for lat=13.1276288, lon=78.1570122, date=20240422 ...
# Fetching DAILY NASA data for lat=12.415911, lon=75.73505, date=20240422 ...
# Fetching DAILY NASA data for lat=12.88925, lon=74.853, date=20240422 ...
# Fetching DAILY NASA data for lat=16.208139, lon=77.348417, date=20240422 ...
# Fetching DAILY NASA data for lat=13.94, lon=75.555917, date=20240422 ...
# Fetching DAILY NASA data for lat=16.802639, lon=75.722694, date=20240422 ...
# Fetching DAILY NASA data for lat=11.875, lon=75.3732, date=20240422 ...
# Fetching DAILY NASA data for lat=33.5489621, lon=133.5987948, date=20240422 ...
# Fetching DAILY NASA data for lat=8.8787, lon=76.6073, date=20240422 ...
# Fetching DAILY NASA data for lat=8.5149093, lon=76.9435879, date=20240422 ...
# Fetching DAILY NASA data for lat=10.5324, lon=76.2159, date=20240422 ...
# Fetching DAILY NASA data for lat=49.5001917595947, lon=0.110902803971606, date=20240422 ...
# Fetching DAILY NASA data for lat=23.233584, lon=77.400574, date=20240422 ...
# Fetching DAILY NASA data for lat=22.9682591, lon=76.064118, date=20240422 ...
# Fetching DAILY NASA data for lat=26.210536, lon=78.171, date=20240422 ...
# Fetching DAILY NASA data for lat=23.168606, lon=79.932247, date=20240422 ...
# Fetching DAILY NASA data for lat=23.331731, lon=75.045981, date=20240422 ...
# Fetching DAILY NASA data for lat=23.8640158, lon=78.80289321, date=20240422 ...
# Fetching DAILY NASA data for lat=24.58434363, lon=80.8549414, date=20240422 ...
# Fetching DAILY NASA data for lat=23.182719, lon=75.768218, date=20240422 ...
# Fetching DAILY NASA data for lat=24.75746, lon=84.366208, date=20240422 ...
# Fetching DAILY NASA data for lat=19.9775302, lon=79.2337086, date=20240422 ...
# Fetching DAILY NASA data for lat=34.2875011, lon=48.787992, date=20240422 ...
# Fetching DAILY NASA data for lat=19.25292, lon=73.142019, date=20240422 ...
# Fetching DAILY NASA data for lat=19.072830200195, lon=72.882606506348, date=20240422 ...
# Fetching DAILY NASA data for lat=21.152875, lon=79.0517531, date=20240422 ...
# Fetching DAILY NASA data for lat=20.0073285, lon=73.7762427, date=20240422 ...
# Fetching DAILY NASA data for lat=17.6599188, lon=75.9063906, date=20240422 ...
# Fetching DAILY NASA data for lat=19.192056, lon=72.9585188, date=20240422 ...
# Fetching DAILY NASA data for lat=24.8207389, lon=93.9423085, date=20240422 ...
# Fetching DAILY NASA data for lat=25.5586, lon=91.8985, date=20240422 ...
# Fetching DAILY NASA data for lat=23.7176342, lon=92.7192841, date=20240422 ...
# Fetching DAILY NASA data for lat=25.6635413, lon=94.0989878, date=20240422 ...
# Fetching DAILY NASA data for lat=50.4651921586212, lon=3.93971432591091, date=20240422 ...
# Fetching DAILY NASA data for lat=11.9309, lon=79.8027, date=20240422 ...
# Fetching DAILY NASA data for lat=31.62, lon=74.876512, date=20240422 ...
# Fetching DAILY NASA data for lat=31.321907, lon=75.578914, date=20240422 ...
# Fetching DAILY NASA data for lat=30.9028, lon=75.8086, date=20240422 ...
# Fetching DAILY NASA data for lat=30.349388, lon=76.366642, date=20240422 ...
# Fetching DAILY NASA data for lat=31.0325454, lon=76.5623046, date=20240422 ...
# Fetching DAILY NASA data for lat=26.470859, lon=74.646594, date=20240422 ...
# Fetching DAILY NASA data for lat=27.554793, lon=76.611536, date=20240422 ...
# Fetching DAILY NASA data for lat=45.262666665757, lon=1.76283333333, date=20240422 ...
# Fetching DAILY NASA data for lat=26.9164092, lon=75.7994901, date=20240422 ...
# Fetching DAILY NASA data for lat=26.268249, lon=73.0193853, date=20240422 ...
# Fetching DAILY NASA data for lat=25.14389, lon=75.821256, date=20240422 ...
# Fetching DAILY NASA data for lat=25.771061, lon=73.340227, date=20240422 ...
# Fetching DAILY NASA data for lat=24.5886166, lon=73.6321397, date=20240422 ...
# Fetching DAILY NASA data for lat=27.33853, lon=88.614099, date=20240422 ...
# Fetching DAILY NASA data for lat=13.087840080261, lon=80.278472900391, date=20240422 ...
# Fetching DAILY NASA data for lat=11.0328, lon=77.0349, date=20240422 ...
# Fetching DAILY NASA data for lat=9.36399, lon=78.831977, date=20240422 ...
# Fetching DAILY NASA data for lat=44.943114, lon=-123.005934, date=20240422 ...
# Fetching DAILY NASA data for lat=11.0973603, lon=77.3228673, date=20240422 ...
# Fetching DAILY NASA data for lat=8.816428, lon=78.099039, date=20240422 ...
# Fetching DAILY NASA data for lat=11.4068288, lon=76.7138973, date=20240422 ...
# Fetching DAILY NASA data for lat=17.585705, lon=78.126199, date=20240422 ...
# Fetching DAILY NASA data for lat=23.8175497, lon=91.2726974, date=20240422 ...
# Fetching DAILY NASA data for lat=27.19865833, lon=78.00598056, date=20240422 ...
# Fetching DAILY NASA data for lat=28.38910936, lon=79.42963708, date=20240422 ...
# Fetching DAILY NASA data for lat=28.406963, lon=77.849831, date=20240422 ...
# Fetching DAILY NASA data for lat=28.685382, lon=77.453839, date=20240422 ...
# Fetching DAILY NASA data for lat=26.730136, lon=83.433859, date=20240422 ...
# Fetching DAILY NASA data for lat=25.4547, lon=78.6039, date=20240422 ...
# Fetching DAILY NASA data for lat=26.428282, lon=80.327067, date=20240422 ...
# Fetching DAILY NASA data for lat=26.766433, lon=80.927299, date=20240422 ...
# Fetching DAILY NASA data for lat=27.571409, lon=77.655757, date=20240422 ...
# Fetching DAILY NASA data for lat=29.06351, lon=77.709723, date=20240422 ...
# Fetching DAILY NASA data for lat=28.856664, lon=78.772638, date=20240422 ...
# Fetching DAILY NASA data for lat=29.4723508, lon=77.7194031, date=20240422 ...
# Fetching DAILY NASA data for lat=25.32393, lon=82.99687, date=20240422 ...
# Fetching DAILY NASA data for lat=23.685297, lon=86.945968, date=20240422 ...
# Fetching DAILY NASA data for lat=22.611968, lon=88.347422, date=20240422 ...
# Fetching DAILY NASA data for lat=22.627847, lon=88.380669, date=20240422 ...
# Fetching DAILY NASA data for lat=22.58157048, lon=88.41002457, date=20240422 ...
# Fetching DAILY NASA data for lat=23.5404352, lon=87.2892225, date=20240422 ...
# Fetching DAILY NASA data for lat=22.5448082, lon=88.3403691, date=20240422 ...
# Fetching DAILY NASA data for lat=22.562629699707, lon=88.363037109375, date=20240422 ...
# Fetching DAILY NASA data for lat=26.6883049, lon=88.412668, date=20240422 ...
# Fetching DAILY NASA data for lat=14.675886, lon=77.593027, date=20240503 ...
# Fetching DAILY NASA data for lat=13.67, lon=79.35, date=20240503 ...
# Fetching DAILY NASA data for lat=27.103358, lon=93.679645, date=20240503 ...
# Fetching DAILY NASA data for lat=26.1875, lon=91.744194, date=20240503 ...
# Fetching DAILY NASA data for lat=25.204762, lon=85.51496, date=20240503 ...
# Fetching DAILY NASA data for lat=26.80365, lon=84.51954, date=20240503 ...
# Fetching DAILY NASA data for lat=25.251013, lon=86.989001, date=20240503 ...
# Fetching DAILY NASA data for lat=24.762518, lon=84.982348, date=20240503 ...
# Fetching DAILY NASA data for lat=25.7808257, lon=84.7446768, date=20240503 ...
# Fetching DAILY NASA data for lat=24.7955, lon=84.9994, date=20240503 ...
# Fetching DAILY NASA data for lat=25.697189, lon=85.2459, date=20240503 ...
# Fetching DAILY NASA data for lat=25.376776, lon=86.471523, date=20240503 ...
# Fetching DAILY NASA data for lat=25.560083, lon=87.553265, date=20240503 ...
# Fetching DAILY NASA data for lat=26.11442, lon=85.39813, date=20240503 ...
# Fetching DAILY NASA data for lat=25.6103665, lon=85.1327137, date=20240503 ...
# Fetching DAILY NASA data for lat=25.892357, lon=86.590325, date=20240503 ...
# Fetching DAILY NASA data for lat=25.859655, lon=85.77944, date=20240503 ...
# Fetching DAILY NASA data for lat=26.2271665, lon=84.3570427, date=20240503 ...
# Fetching DAILY NASA data for lat=30.735567, lon=76.775714, date=20240503 ...
# Fetching DAILY NASA data for lat=21.185571, lon=81.343175, date=20240503 ...
# Fetching DAILY NASA data for lat=22.08815, lon=82.13737, date=20240503 ...
# Fetching DAILY NASA data for lat=30.269444, lon=78.044167, date=20240503 ...
# Fetching DAILY NASA data for lat=20.362421, lon=72.918013, date=20240503 ...
# Fetching DAILY NASA data for lat=28.63576, lon=77.22445, date=20240503 ...
# Fetching DAILY NASA data for lat=23.002657, lon=72.591912, date=20240503 ...
# Fetching DAILY NASA data for lat=21.613267, lon=73.010555, date=20240503 ...
# Fetching DAILY NASA data for lat=23.163798, lon=72.677768, date=20240503 ...
# Fetching DAILY NASA data for lat=30.379589, lon=76.778328, date=20240503 ...
# Fetching DAILY NASA data for lat=28.806223, lon=76.141105, date=20240503 ...
# Fetching DAILY NASA data for lat=28.4088421, lon=77.3099081, date=20240503 ...
# Fetching DAILY NASA data for lat=29.307814, lon=76.337619, date=20240503 ...
# Fetching DAILY NASA data for lat=29.6953, lon=77.0027, date=20240503 ...
# Fetching DAILY NASA data for lat=29.5364, lon=75.0158, date=20240503 ...
# Fetching DAILY NASA data for lat=29.0272, lon=77.0621, date=20240503 ...
# Fetching DAILY NASA data for lat=51.547479, lon=7.693785, date=20240503 ...
# Fetching DAILY NASA data for lat=12.938539, lon=77.5901, date=20240503 ...
# Fetching DAILY NASA data for lat=15.888653, lon=74.541751, date=20240503 ...
# Fetching DAILY NASA data for lat=13.328028, lon=75.797056, date=20240503 ...
# Fetching DAILY NASA data for lat=14.4758, lon=75.9052, date=20240503 ...
# Fetching DAILY NASA data for lat=13.008556, lon=76.125258, date=20240503 ...
# Fetching DAILY NASA data for lat=17.321993, lon=76.822628, date=20240503 ...
# Fetching DAILY NASA data for lat=13.1276288, lon=78.1570122, date=20240503 ...
# Fetching DAILY NASA data for lat=12.415911, lon=75.73505, date=20240503 ...
# Fetching DAILY NASA data for lat=12.88925, lon=74.853, date=20240503 ...
# Fetching DAILY NASA data for lat=13.94, lon=75.555917, date=20240503 ...
# Fetching DAILY NASA data for lat=16.802639, lon=75.722694, date=20240503 ...
# Fetching DAILY NASA data for lat=11.875, lon=75.3732, date=20240503 ...
# Fetching DAILY NASA data for lat=33.5489621, lon=133.5987948, date=20240503 ...
# Fetching DAILY NASA data for lat=8.8787, lon=76.6073, date=20240503 ...
# Fetching DAILY NASA data for lat=8.5149093, lon=76.9435879, date=20240503 ...
# Fetching DAILY NASA data for lat=10.5324, lon=76.2159, date=20240503 ...
# Fetching DAILY NASA data for lat=49.5001917595947, lon=0.110902803971606, date=20240503 ...
# Fetching DAILY NASA data for lat=23.233584, lon=77.400574, date=20240503 ...
# Fetching DAILY NASA data for lat=22.9682591, lon=76.064118, date=20240503 ...
# Fetching DAILY NASA data for lat=26.210536, lon=78.171, date=20240503 ...
# Fetching DAILY NASA data for lat=23.168606, lon=79.932247, date=20240503 ...
# Fetching DAILY NASA data for lat=23.331731, lon=75.045981, date=20240503 ...
# Fetching DAILY NASA data for lat=23.8640158, lon=78.80289321, date=20240503 ...
# Fetching DAILY NASA data for lat=24.58434363, lon=80.8549414, date=20240503 ...
# Fetching DAILY NASA data for lat=23.182719, lon=75.768218, date=20240502 ...
# Fetching DAILY NASA data for lat=24.75746, lon=84.366208, date=20240503 ...
# Fetching DAILY NASA data for lat=34.2875011, lon=48.787992, date=20240503 ...
# Fetching DAILY NASA data for lat=21.152875, lon=79.0517531, date=20240503 ...
# Fetching DAILY NASA data for lat=20.0073285, lon=73.7762427, date=20240503 ...
# Fetching DAILY NASA data for lat=17.6599188, lon=75.9063906, date=20240503 ...
# Fetching DAILY NASA data for lat=19.192056, lon=72.9585188, date=20240503 ...
# Fetching DAILY NASA data for lat=24.8207389, lon=93.9423085, date=20240503 ...
# Fetching DAILY NASA data for lat=25.5586, lon=91.8985, date=20240503 ...
# Fetching DAILY NASA data for lat=23.7176342, lon=92.7192841, date=20240503 ...
# Fetching DAILY NASA data for lat=25.6635413, lon=94.0989878, date=20240503 ...
# Fetching DAILY NASA data for lat=50.4651921586212, lon=3.93971432591091, date=20240503 ...
# Fetching DAILY NASA data for lat=11.9309, lon=79.8027, date=20240503 ...
# Fetching DAILY NASA data for lat=31.62, lon=74.876512, date=20240503 ...
# Fetching DAILY NASA data for lat=31.321907, lon=75.578914, date=20240503 ...
# Fetching DAILY NASA data for lat=30.9028, lon=75.8086, date=20240503 ...
# Fetching DAILY NASA data for lat=30.349388, lon=76.366642, date=20240503 ...
# Fetching DAILY NASA data for lat=31.0325454, lon=76.5623046, date=20240503 ...
# Fetching DAILY NASA data for lat=26.470859, lon=74.646594, date=20240503 ...
# Fetching DAILY NASA data for lat=27.554793, lon=76.611536, date=20240503 ...
# Fetching DAILY NASA data for lat=45.262666665757, lon=1.76283333333, date=20240503 ...
# Fetching DAILY NASA data for lat=26.9164092, lon=75.7994901, date=20240503 ...
# Fetching DAILY NASA data for lat=26.268249, lon=73.0193853, date=20240503 ...
# Fetching DAILY NASA data for lat=25.14389, lon=75.821256, date=20240503 ...
# Fetching DAILY NASA data for lat=25.771061, lon=73.340227, date=20240503 ...
# Fetching DAILY NASA data for lat=24.5886166, lon=73.6321397, date=20240503 ...
# Fetching DAILY NASA data for lat=27.33853, lon=88.614099, date=20240503 ...
# Fetching DAILY NASA data for lat=13.087840080261, lon=80.278472900391, date=20240503 ...
# Fetching DAILY NASA data for lat=9.36399, lon=78.831977, date=20240503 ...
# Fetching DAILY NASA data for lat=44.943114, lon=-123.005934, date=20240502 ...
# Fetching DAILY NASA data for lat=8.816428, lon=78.099039, date=20240503 ...
# Fetching DAILY NASA data for lat=11.4068288, lon=76.7138973, date=20240503 ...
# Fetching DAILY NASA data for lat=17.384050369263, lon=78.456359863281, date=20240503 ...
# Fetching DAILY NASA data for lat=17.585705, lon=78.126199, date=20240503 ...
# Fetching DAILY NASA data for lat=23.8175497, lon=91.2726974, date=20240503 ...
# Fetching DAILY NASA data for lat=27.19865833, lon=78.00598056, date=20240503 ...
# Fetching DAILY NASA data for lat=28.38910936, lon=79.42963708, date=20240503 ...
# Fetching DAILY NASA data for lat=28.406963, lon=77.849831, date=20240503 ...
# Fetching DAILY NASA data for lat=28.685382, lon=77.453839, date=20240503 ...
# Fetching DAILY NASA data for lat=26.730136, lon=83.433859, date=20240503 ...
# Fetching DAILY NASA data for lat=25.4547, lon=78.6039, date=20240503 ...
# Fetching DAILY NASA data for lat=26.428282, lon=80.327067, date=20240503 ...
# Fetching DAILY NASA data for lat=26.766433, lon=80.927299, date=20240503 ...
# Fetching DAILY NASA data for lat=27.571409, lon=77.655757, date=20240503 ...
# Fetching DAILY NASA data for lat=29.06351, lon=77.709723, date=20240503 ...
# ...
# Fetching DAILY NASA data for lat=14.4758, lon=75.9052, date=20240430 ...
# Fetching DAILY NASA data for lat=17.321993, lon=76.822628, date=20240430 ...
# Fetching DAILY NASA data for lat=13.1276288, lon=78.1570122, date=20240430 ...
# Fetching DAILY NASA data for lat=12.415911, lon=75.73505, date=20240430 ...
# Fetching DAILY NASA data for lat=12.88925, lon=74.853, date=20240430 ...
# Fetching DAILY NASA data for lat=13.94, lon=75.555917, date=20240430 ...
# Fetching DAILY NASA data for lat=16.802639, lon=75.722694, date=20240430 ...
# Fetching DAILY NASA data for lat=11.875, lon=75.3732, date=20240430 ...
# Fetching DAILY NASA data for lat=33.5489621, lon=133.5987948, date=20240430 ...
# Fetching DAILY NASA data for lat=8.5149093, lon=76.9435879, date=20240430 ...
# Fetching DAILY NASA data for lat=10.5324, lon=76.2159, date=20240430 ...
# Fetching DAILY NASA data for lat=49.4896322869577, lon=0.100702489901362, date=20240430 ...
# Fetching DAILY NASA data for lat=23.233584, lon=77.400574, date=20240430 ...
# Fetching DAILY NASA data for lat=22.9682591, lon=76.064118, date=20240430 ...
# Fetching DAILY NASA data for lat=26.210536, lon=78.171, date=20240430 ...
# Fetching DAILY NASA data for lat=23.168606, lon=79.932247, date=20240430 ...
# Fetching DAILY NASA data for lat=23.331731, lon=75.045981, date=20240430 ...
# Fetching DAILY NASA data for lat=23.8640158, lon=78.80289321, date=20240430 ...
# Fetching DAILY NASA data for lat=24.58434363, lon=80.8549414, date=20240430 ...
# Fetching DAILY NASA data for lat=23.182719, lon=75.768218, date=20240430 ...
# Fetching DAILY NASA data for lat=24.75746, lon=84.366208, date=20240430 ...
# Fetching DAILY NASA data for lat=34.2875011, lon=48.787992, date=20240430 ...
# Fetching DAILY NASA data for lat=19.25292, lon=73.142019, date=20240430 ...
# Fetching DAILY NASA data for lat=21.152875, lon=79.0517531, date=20240430 ...
# Fetching DAILY NASA data for lat=20.0073285, lon=73.7762427, date=20240430 ...
# Fetching DAILY NASA data for lat=17.6599188, lon=75.9063906, date=20240430 ...
# Fetching DAILY NASA data for lat=24.8207389, lon=93.9423085, date=20240430 ...
# Fetching DAILY NASA data for lat=25.5586, lon=91.8985, date=20240430 ...
# Fetching DAILY NASA data for lat=23.7176342, lon=92.7192841, date=20240430 ...
# Fetching DAILY NASA data for lat=25.6635413, lon=94.0989878, date=20240430 ...
# Fetching DAILY NASA data for lat=50.4651921586212, lon=3.93971432591091, date=20240430 ...
# Fetching DAILY NASA data for lat=11.9309, lon=79.8027, date=20240430 ...
# Fetching DAILY NASA data for lat=31.62, lon=74.876512, date=20240430 ...
# Fetching DAILY NASA data for lat=31.321907, lon=75.578914, date=20240430 ...
# Fetching DAILY NASA data for lat=30.9028, lon=75.8086, date=20240430 ...
# Fetching DAILY NASA data for lat=30.349388, lon=76.366642, date=20240430 ...
# Fetching DAILY NASA data for lat=31.0325454, lon=76.5623046, date=20240430 ...
# Fetching DAILY NASA data for lat=26.470859, lon=74.646594, date=20240430 ...
# Fetching DAILY NASA data for lat=27.554793, lon=76.611536, date=20240430 ...
# Fetching DAILY NASA data for lat=45.262666665757, lon=1.76283333333, date=20240430 ...
# Fetching DAILY NASA data for lat=26.9164092, lon=75.7994901, date=20240430 ...
# Fetching DAILY NASA data for lat=26.268249, lon=73.0193853, date=20240430 ...
# Fetching DAILY NASA data for lat=25.14389, lon=75.821256, date=20240430 ...
# Fetching DAILY NASA data for lat=25.771061, lon=73.340227, date=20240430 ...
# Fetching DAILY NASA data for lat=24.5886166, lon=73.6321397, date=20240430 ...
# Fetching DAILY NASA data for lat=27.33853, lon=88.614099, date=20240430 ...
# Fetching DAILY NASA data for lat=13.087840080261, lon=80.278472900391, date=20240430 ...
# Fetching DAILY NASA data for lat=9.36399, lon=78.831977, date=20240430 ...
# Fetching DAILY NASA data for lat=8.816428, lon=78.099039, date=20240430 ...
# Fetching DAILY NASA data for lat=11.4068288, lon=76.7138973, date=20240430 ...
# Fetching DAILY NASA data for lat=17.384050369263, lon=78.456359863281, date=20240430 ...
# Fetching DAILY NASA data for lat=17.585705, lon=78.126199, date=20240430 ...
# Fetching DAILY NASA data for lat=23.8175497, lon=91.2726974, date=20240430 ...
# Fetching DAILY NASA data for lat=27.19865833, lon=78.00598056, date=20240430 ...
# Fetching DAILY NASA data for lat=28.38910936, lon=79.42963708, date=20240430 ...
# Fetching DAILY NASA data for lat=28.406963, lon=77.849831, date=20240430 ...
# Fetching DAILY NASA data for lat=28.685382, lon=77.453839, date=20240430 ...
# Fetching DAILY NASA data for lat=26.730136, lon=83.433859, date=20240430 ...
# Fetching DAILY NASA data for lat=25.4547, lon=78.6039, date=20240430 ...
# Fetching DAILY NASA data for lat=26.428282, lon=80.327067, date=20240430 ...
# Fetching DAILY NASA data for lat=26.766433, lon=80.927299, date=20240430 ...
# Fetching DAILY NASA data for lat=27.571409, lon=77.655757, date=20240430 ...
# Fetching DAILY NASA data for lat=29.06351, lon=77.709723, date=20240430 ...
# Fetching DAILY NASA data for lat=28.856664, lon=78.772638, date=20240430 ...
# Fetching DAILY NASA data for lat=29.4723508, lon=77.7194031, date=20240430 ...
# Fetching DAILY NASA data for lat=25.32393, lon=82.99687, date=20240430 ...
# Fetching DAILY NASA data for lat=23.685297, lon=86.945968, date=20240430 ...
# Fetching DAILY NASA data for lat=22.611968, lon=88.347422, date=20240430 ...
# Fetching DAILY NASA data for lat=22.627847, lon=88.380669, date=20240430 ...
# Fetching DAILY NASA data for lat=22.58157048, lon=88.41002457, date=20240430 ...
# Fetching DAILY NASA data for lat=23.5404352, lon=87.2892225, date=20240430 ...
# Fetching DAILY NASA data for lat=22.5448082, lon=88.3403691, date=20240430 ...
# Fetching DAILY NASA data for lat=22.562629699707, lon=88.363037109375, date=20240430 ...
# Fetching DAILY NASA data for lat=26.6883049, lon=88.412668, date=20240430 ...
# Fetching DAILY NASA data for lat=14.675886, lon=77.593027, date=20240421 ...
# Fetching DAILY NASA data for lat=16.9872867, lon=81.7363176, date=20240421 ...
# Fetching DAILY NASA data for lat=13.67, lon=79.35, date=20240421 ...
# Fetching DAILY NASA data for lat=27.103358, lon=93.679645, date=20240417 ...
# Fetching DAILY NASA data for lat=25.204762, lon=85.51496, date=20240421 ...
# Fetching DAILY NASA data for lat=25.5626095, lon=84.663264, date=20240419 ...
# Fetching DAILY NASA data for lat=26.80365, lon=84.51954, date=20240421 ...
# Fetching DAILY NASA data for lat=25.251013, lon=86.989001, date=20240421 ...
# Fetching DAILY NASA data for lat=24.762518, lon=84.982348, date=20240421 ...
# Fetching DAILY NASA data for lat=25.7808257, lon=84.7446768, date=20240421 ...
# Fetching DAILY NASA data for lat=24.7955, lon=84.9994, date=20240421 ...
# Fetching DAILY NASA data for lat=25.697189, lon=85.2459, date=20240421 ...
# Fetching DAILY NASA data for lat=25.376776, lon=86.471523, date=20240421 ...
# Fetching DAILY NASA data for lat=25.560083, lon=87.553265, date=20240421 ...
# Fetching DAILY NASA data for lat=26.63086, lon=84.90051, date=20240421 ...
# Fetching DAILY NASA data for lat=26.11442, lon=85.39813, date=20240421 ...
# Fetching DAILY NASA data for lat=25.6103665, lon=85.1327137, date=20240421 ...
# Fetching DAILY NASA data for lat=25.892357, lon=86.590325, date=20240421 ...
# Fetching DAILY NASA data for lat=25.859655, lon=85.77944, date=20240421 ...
# Fetching DAILY NASA data for lat=26.2271665, lon=84.3570427, date=20240420 ...
# Fetching DAILY NASA data for lat=30.735567, lon=76.775714, date=20240421 ...
# Fetching DAILY NASA data for lat=21.185571, lon=81.343175, date=20240421 ...
# Fetching DAILY NASA data for lat=22.08815, lon=82.13737, date=20240421 ...
# Fetching DAILY NASA data for lat=30.269444, lon=78.044167, date=20240421 ...
# Fetching DAILY NASA data for lat=20.362421, lon=72.918013, date=20240421 ...
# Fetching DAILY NASA data for lat=28.63576, lon=77.22445, date=20240421 ...
# Fetching DAILY NASA data for lat=23.002657, lon=72.591912, date=20240421 ...
# Fetching DAILY NASA data for lat=21.613267, lon=73.010555, date=20240421 ...
# Fetching DAILY NASA data for lat=23.243639, lon=72.68994, date=20240421 ...
# Fetching DAILY NASA data for lat=30.379589, lon=76.778328, date=20240421 ...
# Fetching DAILY NASA data for lat=28.806223, lon=76.141105, date=20240421 ...
# Fetching DAILY NASA data for lat=28.4088421, lon=77.3099081, date=20240421 ...
# Fetching DAILY NASA data for lat=29.14056, lon=75.744941, date=20240421 ...
# Fetching DAILY NASA data for lat=29.307814, lon=76.337619, date=20240421 ...
# Fetching DAILY NASA data for lat=29.8006, lon=76.4155, date=20240421 ...
# Fetching DAILY NASA data for lat=29.6953, lon=77.0027, date=20240421 ...
# Fetching DAILY NASA data for lat=29.5364, lon=75.0158, date=20240421 ...
# Fetching DAILY NASA data for lat=29.0272, lon=77.0621, date=20240421 ...
# Fetching DAILY NASA data for lat=51.547479, lon=7.693785, date=20240421 ...
# Fetching DAILY NASA data for lat=23.707909, lon=86.41467, date=20240421 ...
# Fetching DAILY NASA data for lat=12.938539, lon=77.5901, date=20240421 ...
# Fetching DAILY NASA data for lat=15.888653, lon=74.541751, date=20240421 ...
# Fetching DAILY NASA data for lat=13.328028, lon=75.797056, date=20240421 ...
# Fetching DAILY NASA data for lat=14.4758, lon=75.9052, date=20240421 ...
# Fetching DAILY NASA data for lat=13.008556, lon=76.125258, date=20240421 ...
# Fetching DAILY NASA data for lat=17.321993, lon=76.822628, date=20240421 ...
# Fetching DAILY NASA data for lat=13.1276288, lon=78.1570122, date=20240421 ...
# Fetching DAILY NASA data for lat=12.415911, lon=75.73505, date=20240421 ...
# Fetching DAILY NASA data for lat=12.88925, lon=74.853, date=20240421 ...
# Fetching DAILY NASA data for lat=16.208139, lon=77.348417, date=20240411 ...
# Fetching DAILY NASA data for lat=13.94, lon=75.555917, date=20240421 ...
# Fetching DAILY NASA data for lat=16.802639, lon=75.722694, date=20240421 ...
# Fetching DAILY NASA data for lat=11.875, lon=75.3732, date=20240421 ...
# Fetching DAILY NASA data for lat=33.5489621, lon=133.5987948, date=20240421 ...
# Fetching DAILY NASA data for lat=8.8787, lon=76.6073, date=20240421 ...
# Fetching DAILY NASA data for lat=8.5149093, lon=76.9435879, date=20240421 ...
# Fetching DAILY NASA data for lat=10.5324, lon=76.2159, date=20240421 ...
# Fetching DAILY NASA data for lat=49.5001917595947, lon=0.110902803971606, date=20240421 ...
# Fetching DAILY NASA data for lat=23.233584, lon=77.400574, date=20240421 ...
# Fetching DAILY NASA data for lat=22.9682591, lon=76.064118, date=20240421 ...
# Fetching DAILY NASA data for lat=26.210536, lon=78.171, date=20240421 ...
# Fetching DAILY NASA data for lat=23.168606, lon=79.932247, date=20240421 ...
# Fetching DAILY NASA data for lat=23.331731, lon=75.045981, date=20240421 ...
# Fetching DAILY NASA data for lat=23.8640158, lon=78.80289321, date=20240421 ...
# Fetching DAILY NASA data for lat=24.58434363, lon=80.8549414, date=20240421 ...
# Fetching DAILY NASA data for lat=23.182719, lon=75.768218, date=20240420 ...
# Fetching DAILY NASA data for lat=24.75746, lon=84.366208, date=20240421 ...
# Fetching DAILY NASA data for lat=19.9775302, lon=79.2337086, date=20240421 ...
# Fetching DAILY NASA data for lat=34.2875011, lon=48.787992, date=20240421 ...
# Fetching DAILY NASA data for lat=19.25292, lon=73.142019, date=20240421 ...
# Fetching DAILY NASA data for lat=19.072830200195, lon=72.882606506348, date=20240421 ...
# Fetching DAILY NASA data for lat=21.152875, lon=79.0517531, date=20240421 ...
# Fetching DAILY NASA data for lat=20.0073285, lon=73.7762427, date=20240421 ...
# Fetching DAILY NASA data for lat=17.6599188, lon=75.9063906, date=20240421 ...
# Fetching DAILY NASA data for lat=19.192056, lon=72.9585188, date=20240421 ...
# Fetching DAILY NASA data for lat=24.8207389, lon=93.9423085, date=20240421 ...
# Fetching DAILY NASA data for lat=25.5586, lon=91.8985, date=20240421 ...
# Fetching DAILY NASA data for lat=23.7176342, lon=92.7192841, date=20240421 ...
# Fetching DAILY NASA data for lat=25.6635413, lon=94.0989878, date=20240421 ...
# Fetching DAILY NASA data for lat=50.4651921586212, lon=3.93971432591091, date=20240421 ...
# Fetching DAILY NASA data for lat=11.9309, lon=79.8027, date=20240421 ...
# Fetching DAILY NASA data for lat=31.62, lon=74.876512, date=20240421 ...
# Fetching DAILY NASA data for lat=31.321907, lon=75.578914, date=20240421 ...
# Fetching DAILY NASA data for lat=30.9028, lon=75.8086, date=20240421 ...
# Fetching DAILY NASA data for lat=30.349388, lon=76.366642, date=20240421 ...
# Fetching DAILY NASA data for lat=31.0325454, lon=76.5623046, date=20240421 ...
# Fetching DAILY NASA data for lat=26.470859, lon=74.646594, date=20240421 ...
# Fetching DAILY NASA data for lat=27.554793, lon=76.611536, date=20240421 ...
# Fetching DAILY NASA data for lat=45.262666665757, lon=1.76283333333, date=20240421 ...
# Fetching DAILY NASA data for lat=26.9164092, lon=75.7994901, date=20240421 ...
# Fetching DAILY NASA data for lat=26.268249, lon=73.0193853, date=20240421 ...
# Fetching DAILY NASA data for lat=25.14389, lon=75.821256, date=20240421 ...
# Fetching DAILY NASA data for lat=25.771061, lon=73.340227, date=20240421 ...
# Fetching DAILY NASA data for lat=24.5886166, lon=73.6321397, date=20240421 ...
# Fetching DAILY NASA data for lat=27.33853, lon=88.614099, date=20240421 ...
# Fetching DAILY NASA data for lat=13.087840080261, lon=80.278472900391, date=20240421 ...
# Fetching DAILY NASA data for lat=9.36399, lon=78.831977, date=20240420 ...
# Fetching DAILY NASA data for lat=44.943114, lon=-123.005934, date=20240421 ...
# Fetching DAILY NASA data for lat=11.0973603, lon=77.3228673, date=20240421 ...
# Fetching DAILY NASA data for lat=8.816428, lon=78.099039, date=20240421 ...
# Fetching DAILY NASA data for lat=11.4068288, lon=76.7138973, date=20240421 ...
# Fetching DAILY NASA data for lat=17.384050369263, lon=78.456359863281, date=20240421 ...
# Fetching DAILY NASA data for lat=17.585705, lon=78.126199, date=20240421 ...
# Fetching DAILY NASA data for lat=23.8175497, lon=91.2726974, date=20240421 ...
# Fetching DAILY NASA data for lat=27.19865833, lon=78.00598056, date=20240421 ...
# Fetching DAILY NASA data for lat=28.38910936, lon=79.42963708, date=20240421 ...
# Fetching DAILY NASA data for lat=28.406963, lon=77.849831, date=20240421 ...
# Fetching DAILY NASA data for lat=28.685382, lon=77.453839, date=20240421 ...
# Fetching DAILY NASA data for lat=26.730136, lon=83.433859, date=20240421 ...
# Fetching DAILY NASA data for lat=25.4547, lon=78.6039, date=20240421 ...
# Fetching DAILY NASA data for lat=26.428282, lon=80.327067, date=20240421 ...
# Fetching DAILY NASA data for lat=26.766433, lon=80.927299, date=20240421 ...
# Fetching DAILY NASA data for lat=27.571409, lon=77.655757, date=20240421 ...
# Fetching DAILY NASA data for lat=29.06351, lon=77.709723, date=20240421 ...
# Fetching DAILY NASA data for lat=28.856664, lon=78.772638, date=20240421 ...
# Fetching DAILY NASA data for lat=29.4723508, lon=77.7194031, date=20240421 ...
# Fetching DAILY NASA data for lat=25.32393, lon=82.99687, date=20240421 ...
# Fetching DAILY NASA data for lat=23.685297, lon=86.945968, date=20240421 ...
# Fetching DAILY NASA data for lat=22.611968, lon=88.347422, date=20240421 ...
# Fetching DAILY NASA data for lat=22.627847, lon=88.380669, date=20240421 ...
# Fetching DAILY NASA data for lat=22.58157048, lon=88.41002457, date=20240421 ...
# Fetching DAILY NASA data for lat=23.5404352, lon=87.2892225, date=20240421 ...
# Fetching DAILY NASA data for lat=22.5448082, lon=88.3403691, date=20240421 ...
# Fetching DAILY NASA data for lat=22.562629699707, lon=88.363037109375, date=20240421 ...
# Fetching DAILY NASA data for lat=26.6883049, lon=88.412668, date=20240421 ...
# NASA DAILY meteo dataframe preview:
#     Latitude  Longitude nasa_date    T2M   RH2M  WS10M  WD10M  PRECTOTCORR
# 0  14.675886  77.593027  20240501  35.22  33.79   3.94  259.8         0.00
# 1  16.987287  81.736318  20240501  34.87  52.86   4.19  202.5         0.00
# 2  13.670000  79.350000  20240501  35.10  46.06   4.31  176.7         0.00
# 3  16.507014  80.627767  20201119  24.94  87.03   2.44  109.8         0.00
# 4  27.103358  93.679645  20240501  25.98  66.55   3.14  222.0         3.16

# %%
merged = df.merge(
    nasa_df,
    on=["Latitude", "Longitude", "nasa_date"],
    how="left"
)

# %%
merged.head()
# Out:
#                                             City  AQI  PM2.5  PM10    O3  \
# 0                    Gulzarpet, Anantapur, India   75   75.0  61.0   6.8
# 1  Anand Kala Kshetram, Rajamahendravaram, India   19    5.0  19.0   6.5
# 2                Tirumala-APPCB, Tirupati, India   90   90.0  58.0  12.5
# 3                 PWD Grounds, Vijayawada, India    -   52.0   NaN   5.1
# 4                  Naharlagun, Naharlagun, India  127  127.0  57.0   1.0
#
#     NO2  SO2   CO   Latitude  Longitude                Time nasa_date  \
# 0   4.7  3.6  7.2  14.675886  77.593027 2024-05-01 09:00:00  20240501
# 1   1.1  4.7  5.8  16.987287  81.736318 2024-05-01 05:00:00  20240501
# 2  10.0  4.1  7.3  13.670000  79.350000 2024-05-01 10:00:00  20240501
# 3   0.7  4.9  4.2  16.507014  80.627767 2020-11-19 16:00:00  20201119
# 4   1.1  1.7  2.8  27.103358  93.679645 2024-05-01 10:00:00  20240501
#
#   hour_str    T2M   RH2M  WS10M  WD10M  PRECTOTCORR
# 0       09  35.22  33.79   3.94  259.8         0.00
# 1       05  34.87  52.86   4.19  202.5         0.00
# 2       10  35.10  46.06   4.31  176.7         0.00
# 3       16  24.94  87.03   2.44  109.8         0.00
# 4       10  25.98  66.55   3.14  222.0         3.16

# %%
import pandas as pd

# 1. Load your dataset
df = merged.copy()

# ---------------------------------------------------
# 2. Clean column names (strip spaces)
#    (we keep original case because your columns are case-sensitive)
# ---------------------------------------------------
df.columns = df.columns.str.strip()

print("Original columns:", df.columns.tolist())

# ---------------------------------------------------
# 3. Detect and standardise timestamp column
# ---------------------------------------------------
time_candidates = ["timestamp", "Timestamp", "time", "Time", "TIME"]

time_col = None
for c in time_candidates:
    if c in df.columns:
        time_col = c
        break

if time_col is None:
    raise KeyError(
        f"No time/timestamp-like column found. Columns are: {df.columns.tolist()}"
    )

# Rename whatever we found to 'timestamp'
if time_col != "timestamp":
    df = df.rename(columns={time_col: "timestamp"})

# Convert to datetime
df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce")

# ---------------------------------------------------
# 4. Rename other columns if they exist
#    (we only rename if the old name is present)
# ---------------------------------------------------
rename_map = {
    "pm2.5": "pm25_ugm3",
    "PM2.5": "pm25_ugm3",
    "co": "co_ppm",
    "CO": "co_ppm",
    "no2": "no2_ppb",
    "NO2": "no2_ppb",
    "so2": "so2_ppb",
    "SO2": "so2_ppb",
    "o3": "o3_ppb",
    "O3": "o3_ppb",
    "t2m": "temperature_c",
    "T2M": "temperature_c",
    "rh2m": "relative_humidity",
    "RH2M": "relative_humidity",
    "ws10m": "wind_speed_ms",
    "WS10M": "wind_speed_ms",
    "wd10m": "wind_direction_deg",
    "WD10M": "wind_direction_deg",
    "aqi": "aqi_value",
    "AQI": "aqi_value",
    "Latitude": "latitude",
    "Longitude":"longitude",
}

for old, new in rename_map.items():
    if old in df.columns and new not in df.columns:
        df = df.rename(columns={old: new})

# ---------------------------------------------------
# 5. Ensure we have all final columns (create if missing)
# ---------------------------------------------------
desired_cols = [
    "timestamp",
    "latitude",
    "longitude",
    "pm25_ugm3",
    "co_ppm",
    "no2_ppb",
    "so2_ppb",
    "o3_ppb",
    "temperature_c",
    "relative_humidity",
    "wind_speed_ms",
    "wind_direction_deg",
    "aqi_value",
    "aqi_category",
    "binary_label",
    "calibration_factor",
]

for col in desired_cols:
    if col not in df.columns:
        df[col] = pd.NA

# ---------------------------------------------------
# 6. Reorder columns to the exact schema
# ---------------------------------------------------
df = df[desired_cols]




# Optional: save cleaned dataset
# df.to_excel(
#     "/Users/ravigurjar/Desktop/temp/sample/dessertation/data/final_aqi_dataset.xlsx",
#     index=False,
# )
# Out:
# Original columns: ['City', 'AQI', 'PM2.5', 'PM10', 'O3', 'NO2', 'SO2', 'CO', 'Latitude', 'Longitude', 'Time', 'nasa_date', 'hour_str', 'T2M', 'RH2M', 'WS10M', 'WD10M', 'PRECTOTCORR']

# %%
df.head()
# Out:
#             timestamp   latitude  longitude  pm25_ugm3  co_ppm  no2_ppb  \
# 0 2024-05-01 09:00:00  14.675886  77.593027       75.0     7.2      4.7
# 1 2024-05-01 05:00:00  16.987287  81.736318        5.0     5.8      1.1
# 2 2024-05-01 10:00:00  13.670000  79.350000       90.0     7.3     10.0
# 3 2020-11-19 16:00:00  16.507014  80.627767       52.0     4.2      0.7
# 4 2024-05-01 10:00:00  27.103358  93.679645      127.0     2.8      1.1
#
#    so2_ppb  o3_ppb  temperature_c  relative_humidity  wind_speed_ms  \
# 0      3.6     6.8          35.22              33.79           3.94
# 1      4.7     6.5          34.87              52.86           4.19
# 2      4.1    12.5          35.10              46.06           4.31
# 3      4.9     5.1          24.94              87.03           2.44
# 4      1.7     1.0          25.98              66.55           3.14
#
#    wind_direction_deg aqi_value aqi_category binary_label calibration_factor
# 0               259.8        75         <NA>         <NA>               <NA>
# 1               202.5        19         <NA>         <NA>               <NA>
# 2               176.7        90         <NA>         <NA>               <NA>
# 3               109.8         -         <NA>         <NA>               <NA>
# 4               222.0       127         <NA>         <NA>               <NA>

# %%
df = df.drop(columns=["aqi_category", "binary_label", "calibration_factor"])

# %%
df
# Out:
#                timestamp   latitude  longitude  pm25_ugm3  co_ppm  no2_ppb  \
# 0    2024-05-01 09:00:00  14.675886  77.593027       75.0     7.2      4.7
# 1    2024-05-01 05:00:00  16.987287  81.736318        5.0     5.8      1.1
# 2    2024-05-01 10:00:00  13.670000  79.350000       90.0     7.3     10.0
# 3    2020-11-19 16:00:00  16.507014  80.627767       52.0     4.2      0.7
# 4    2024-05-01 10:00:00  27.103358  93.679645      127.0     2.8      1.1
# ...                  ...        ...        ...        ...     ...      ...
# 1831 2024-05-01 10:00:00  22.544808  88.340369      127.0    10.1     12.8
# 1832 2024-05-01 10:00:00  22.627847  88.380669      106.0     6.8     12.6
# 1833 2024-05-01 09:00:00  22.562630  88.363037      162.0     NaN      NaN
# 1834 2024-05-01 10:00:00  22.627847  88.380669      106.0     6.8     12.6
# 1835 2024-05-01 10:00:00  26.688305  88.412668       89.0     4.1     11.6
#
#       so2_ppb  o3_ppb  temperature_c  relative_humidity  wind_speed_ms  \
# 0         3.6     6.8          35.22              33.79           3.94
# 1         4.7     6.5          34.87              52.86           4.19
# 2         4.1    12.5          35.10              46.06           4.31
# 3         4.9     5.1          24.94              87.03           2.44
# 4         1.7     1.0          25.98              66.55           3.14
# ...       ...     ...            ...                ...            ...
# 1831      9.3    27.1          36.68              40.92           3.62
# 1832      2.6    35.4          36.68              40.92           3.62
# 1833      NaN     NaN          36.68              40.92           3.62
# 1834      2.6    35.4          36.68              40.92           3.62
# 1835      3.3    17.1          32.29              17.85           5.36
#
#       wind_direction_deg aqi_value
# 0                  259.8        75
# 1                  202.5        19
# 2                  176.7        90
# 3                  109.8         -
# 4                  222.0       127
# ...                  ...       ...
# 1831               228.4       127
# 1832               228.4       106
# 1833               228.4       162
# 1834               228.4       106
# 1835               260.9        89
#
# [1836 rows x 13 columns]

# %%
another_df = pd.read_csv("/Users/ravigurjar/Desktop/temp/sample/dessertation/data/processed/Air quality monitoring data.csv")

# %%
another_df
# Out:
#              timestamp   latitude  longitude  pm25_ugm3  co_ppm  no2_ppb  \
# 0     01/01/2023 00:00  23.892448  90.393656        2.8    2.42     54.3
# 1     01/01/2023 01:00  23.815139  90.379102       36.9    3.38     51.7
# 2     01/01/2023 02:00  23.842481  90.417399       38.3    2.52     74.1
# 3     01/01/2023 03:00  23.808169  90.414357       30.8    2.25     89.4
# 4     01/01/2023 04:00  23.848632  90.370174       10.9    0.95     77.3
# ...                ...        ...        ...        ...     ...      ...
# 5994  09/07/2023 18:00  23.862992  90.445081       11.5    1.59      6.2
# 5995  09/07/2023 19:00  23.832901  90.440574        7.5    0.71      5.3
# 5996  09/07/2023 20:00  23.812617  90.365143        1.5    1.01     12.8
# 5997  09/07/2023 21:00  23.805677  90.374522        3.7    2.10     44.8
# 5998  09/07/2023 22:00  23.774079  90.403201        2.0    1.93     14.8
#
#       so2_ppb  o3_ppb  temperature_c  relative_humidity  wind_speed_ms  \
# 0        10.0    31.0           29.0               41.6            2.3
# 1         6.2    57.5           23.9               42.7            1.1
# 2        16.4   188.9           30.2               52.4            1.9
# 3        21.8   166.1           37.2               46.2            2.4
# 4         8.7    85.6           23.1               54.0            3.9
# ...       ...     ...            ...                ...            ...
# 5994     20.4    18.3           31.9               46.1            2.3
# 5995     11.3    14.7           26.4               74.0            2.5
# 5996      7.9    23.3           34.2               41.4            2.2
# 5997     14.5    69.2           15.3               63.5            1.0
# 5998      6.8    21.6           28.7               81.8            4.2
#
#       wind_direction_deg  aqi_value                    aqi_category  \
# 0                  120.2         11                            Good
# 1                   51.2        104  Unhealthy for Sensitive Groups
# 2                  101.5        108  Unhealthy for Sensitive Groups
# 3                  323.7         90                        Moderate
# 4                   57.4         45                            Good
# ...                  ...        ...                             ...
# 5994               109.8         48                            Good
# 5995               154.9         31                            Good
# 5996                99.1          6                            Good
# 5997               234.5         15                            Good
# 5998                70.2          8                            Good
#
#      binary_label  calibration_factor
# 0            Safe            0.978396
# 1         Harmful            1.010800
# 2         Harmful            0.951336
# 3            Safe            1.040067
# 4            Safe            0.933461
# ...           ...                 ...
# 5994         Safe            1.053097
# 5995         Safe            1.056224
# 5996         Safe            0.982562
# 5997         Safe            1.097383
# 5998         Safe            0.971497
#
# [5999 rows x 16 columns]

# %%
another_df = another_df.drop(columns=["aqi_category", "binary_label", "calibration_factor"])

# %%
another_df
# Out:
#              timestamp   latitude  longitude  pm25_ugm3  co_ppm  no2_ppb  \
# 0     01/01/2023 00:00  23.892448  90.393656        2.8    2.42     54.3
# 1     01/01/2023 01:00  23.815139  90.379102       36.9    3.38     51.7
# 2     01/01/2023 02:00  23.842481  90.417399       38.3    2.52     74.1
# 3     01/01/2023 03:00  23.808169  90.414357       30.8    2.25     89.4
# 4     01/01/2023 04:00  23.848632  90.370174       10.9    0.95     77.3
# ...                ...        ...        ...        ...     ...      ...
# 5994  09/07/2023 18:00  23.862992  90.445081       11.5    1.59      6.2
# 5995  09/07/2023 19:00  23.832901  90.440574        7.5    0.71      5.3
# 5996  09/07/2023 20:00  23.812617  90.365143        1.5    1.01     12.8
# 5997  09/07/2023 21:00  23.805677  90.374522        3.7    2.10     44.8
# 5998  09/07/2023 22:00  23.774079  90.403201        2.0    1.93     14.8
#
#       so2_ppb  o3_ppb  temperature_c  relative_humidity  wind_speed_ms  \
# 0        10.0    31.0           29.0               41.6            2.3
# 1         6.2    57.5           23.9               42.7            1.1
# 2        16.4   188.9           30.2               52.4            1.9
# 3        21.8   166.1           37.2               46.2            2.4
# 4         8.7    85.6           23.1               54.0            3.9
# ...       ...     ...            ...                ...            ...
# 5994     20.4    18.3           31.9               46.1            2.3
# 5995     11.3    14.7           26.4               74.0            2.5
# 5996      7.9    23.3           34.2               41.4            2.2
# 5997     14.5    69.2           15.3               63.5            1.0
# 5998      6.8    21.6           28.7               81.8            4.2
#
#       wind_direction_deg  aqi_value
# 0                  120.2         11
# 1                   51.2        104
# 2                  101.5        108
# 3                  323.7         90
# 4                   57.4         45
# ...                  ...        ...
# 5994               109.8         48
# 5995               154.9         31
# 5996                99.1          6
# 5997               234.5         15
# 5998                70.2          8
#
# [5999 rows x 13 columns]

# %%
final_df = pd.concat([df,another_df])

# %%
final_df
# Out:
#                 timestamp   latitude  longitude  pm25_ugm3  co_ppm  no2_ppb  \
# 0     2024-05-01 09:00:00  14.675886  77.593027       75.0    7.20      4.7
# 1     2024-05-01 05:00:00  16.987287  81.736318        5.0    5.80      1.1
# 2     2024-05-01 10:00:00  13.670000  79.350000       90.0    7.30     10.0
# 3     2020-11-19 16:00:00  16.507014  80.627767       52.0    4.20      0.7
# 4     2024-05-01 10:00:00  27.103358  93.679645      127.0    2.80      1.1
# ...                   ...        ...        ...        ...     ...      ...
# 5994     09/07/2023 18:00  23.862992  90.445081       11.5    1.59      6.2
# 5995     09/07/2023 19:00  23.832901  90.440574        7.5    0.71      5.3
# 5996     09/07/2023 20:00  23.812617  90.365143        1.5    1.01     12.8
# 5997     09/07/2023 21:00  23.805677  90.374522        3.7    2.10     44.8
# 5998     09/07/2023 22:00  23.774079  90.403201        2.0    1.93     14.8
#
#       so2_ppb  o3_ppb  temperature_c  relative_humidity  wind_speed_ms  \
# 0         3.6     6.8          35.22              33.79           3.94
# 1         4.7     6.5          34.87              52.86           4.19
# 2         4.1    12.5          35.10              46.06           4.31
# 3         4.9     5.1          24.94              87.03           2.44
# 4         1.7     1.0          25.98              66.55           3.14
# ...       ...     ...            ...                ...            ...
# 5994     20.4    18.3          31.90              46.10           2.30
# 5995     11.3    14.7          26.40              74.00           2.50
# 5996      7.9    23.3          34.20              41.40           2.20
# 5997     14.5    69.2          15.30              63.50           1.00
# 5998      6.8    21.6          28.70              81.80           4.20
#
#       wind_direction_deg aqi_value
# 0                  259.8        75
# 1                  202.5        19
# 2                  176.7        90
# 3                  109.8         -
# 4                  222.0       127
# ...                  ...       ...
# 5994               109.8        48
# 5995               154.9        31
# 5996                99.1         6
# 5997               234.5        15
# 5998                70.2         8
#
# [7835 rows x 13 columns]

# %%
# Convert to datetime
final_df["timestamp"] = pd.to_datetime(final_df["timestamp"], errors="coerce")

# Format consistently
final_df["timestamp"] = final_df["timestamp"].dt.strftime("%Y-%m-%d %H:%M:%S")

# %%
import os

cleaned_folder = "/Users/ravigurjar/Desktop/temp/sample/dessertation/data/cleaned"
os.makedirs(cleaned_folder, exist_ok=True)

output_path = os.path.join(cleaned_folder, "final_df.csv")

final_df.to_csv(output_path, index=False)

print("Saved successfully to:", output_path)
# Out:
# Saved successfully to: /Users/ravigurjar/Desktop/temp/sample/dessertation/data/cleaned/final_df.csv
